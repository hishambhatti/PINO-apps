# %% [markdown]
# # Import Libraries

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib notebook
from argparse import ArgumentParser
import yaml
import os
import math
import torch
# from torch import vmap
from torch.func import vmap, grad
from models import FNN2d
from train_utils import Adam
# from train_utils.datasets import BurgersLoader
# from train_utils.train_2d import train_2d_burger
# from train_utils.eval_2d import eval_burgers

from solver.WaveEq import WaveEq1D
import traceback

import scipy.io
import torch.nn.functional as F
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import imageio


from tqdm import tqdm
from train_utils.utils import save_checkpoint, load_checkpoint, update_config, load_config
from train_utils.losses import LpLoss
from train_utils.datasets import DataLoader1D

from solver.my_random_fields import GRF_Mattern

from importlib import reload

try:
    import wandb
except ImportError:
    wandb = None
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Define Loss Functions

# %% [markdown]
# ## Spectral Derivatives

# %%
def FDM_Wave(u, D=1, c=1.0):
    batchsize = u.size(0)
    nt = u.size(1)
    nx = u.size(2)

    u = u.reshape(batchsize, nt, nx)
    dt = D / (nt-1)
    dx = D / (nx)

    u_h = torch.fft.fft(u, dim=2)
    # Wavenumbers in y-direction
    k_max = nx//2
    k_x = torch.cat((torch.arange(start=0, end=k_max, step=1, device=u.device),
                     torch.arange(start=-k_max, end=0, step=1, device=u.device)), 0).reshape(1,1,nx)
    ux_h = 2j *np.pi*k_x*u_h
    uxx_h = 2j *np.pi*k_x*ux_h
    ux = torch.fft.irfft(ux_h[:, :, :k_max+1], dim=2, n=nx)
    uxx = torch.fft.irfft(uxx_h[:, :, :k_max+1], dim=2, n=nx)
    ut = (u[:, 2:, :] - u[:, :-2, :]) / (2 * dt)
    utt = (u[:, 2:, :] - 2.0*u[:, 1:-1, :] + u[:, :-2, :]) / (dt**2)
    Du = utt - c**2 * uxx[:,1:-1,:]
    return Du


def PINO_loss_wave(u, u0, c=1.0):
    batchsize = u.size(0)
    nt = u.size(1)
    nx = u.size(2)

    u = u.reshape(batchsize, nt, nx)
    # lploss = LpLoss(size_average=True)

    index_t = torch.zeros(nx,).long()
    index_x = torch.tensor(range(nx)).long()
    boundary_u = u[:, index_t, index_x]
    loss_u = F.mse_loss(boundary_u, u0)

    Du = FDM_Wave(u, c=c)[:, :, :]
    f = torch.zeros(Du.shape, device=u.device)
    loss_f = F.mse_loss(Du, f)

    # loss_bc0 = F.mse_loss(u[:, :, 0], u[:, :, -1])
    # loss_bc1 = F.mse_loss((u[:, :, 1] - u[:, :, -1]) /
    #                       (2/(nx)), (u[:, :, 0] - u[:, :, -2])/(2/(nx)))
    return loss_u, loss_f

# %% [markdown]
# # Define Training Function

# %%
def train_wave(model,
               train_loader,
               optimizer, 
               scheduler,
               config,
               rank=0, 
               log=False,
               project='PINO-2d-default',
               group='default',
               tags=['default'],
               use_tqdm=True):
    if rank == 0 and wandb and log:
        run = wandb.init(project=project,
                         entity='shawngr2',
                         group=group,
                         config=config,
                         tags=tags, reinit=True,
                         settings=wandb.Settings(start_method="fork"))

    data_weight = config['train']['xy_loss']
    f_weight = config['train']['f_loss']
    ic_weight = config['train']['ic_loss']
    c = config['data']['c']
    ckpt_freq = config['train']['ckpt_freq']
    model.train()
    myloss = LpLoss(size_average=True)
    pbar = range(config['train']['epochs'])
    if use_tqdm:
        pbar = tqdm(pbar, dynamic_ncols=True, smoothing=0.1)

    for e in pbar:
        model.train()
        train_pino = 0.0
        data_l2 = 0.0
        train_ic = 0.0
        train_loss = 0.0

        for x, y in train_loader:
            x, y = x.to(rank), y.to(rank)
#             display(x.shape, y.shape)
            out = model(x).reshape(y.shape)
            data_loss = myloss(out, y)

            loss_ic, loss_f = PINO_loss_wave(out, x[:, 0, :, 0], c=c)
            total_loss = loss_ic * ic_weight + loss_f * f_weight + data_loss * data_weight

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            data_l2 += data_loss.item()
            train_pino += loss_f.item()
            train_loss += total_loss.item()
            train_ic += loss_ic.item()
        scheduler.step()
        data_l2 /= len(train_loader)
        train_pino /= len(train_loader)
        train_loss /= len(train_loader)
        if use_tqdm:
            pbar.set_description(
                (
                    f'Epoch {e}, train loss: {train_loss:.5f} '
                    f'train f error: {train_pino:.5f}; '
                    f'data l2 error: {data_l2:.5f}; '
                    f'train ic error: {train_ic:.5f}'
                )
            )
        if wandb and log:
            wandb.log(
                {
                    'Train f error': train_pino,
                    'Train L2 error': data_l2,
                    'Train ic error': loss_ic,
                    'Train loss': train_loss,
                }
            )

        if e % ckpt_freq == 0:
            save_checkpoint(config['train']['save_dir'],
                            config['train']['save_name'].replace('.pt', f'_{e}.pt'),
                            model, optimizer)
    save_checkpoint(config['train']['save_dir'],
                    config['train']['save_name'],
                    model, optimizer)
    print('Done!')

# %% [markdown]
# # Evaluation Function

# %%
def eval_wave(model,
              dataloader,
              config,
              device,
              use_tqdm=True):
    model.eval()
    myloss = LpLoss(size_average=True)
    c = config['data']['c']
    if use_tqdm:
        pbar = tqdm(dataloader, dynamic_ncols=True, smoothing=0.05)
    else:
        pbar = dataloader

    test_err = []
    f_err = []

    for x, y in pbar:
        x, y = x.to(device), y.to(device)
        out = model(x).reshape(y.shape)
        data_loss = myloss(out, y)

        loss_u, f_loss = PINO_loss_wave(out, x[:, 0, :, 0], c=c)
        test_err.append(data_loss.item())
        f_err.append(f_loss.item())

    mean_f_err = np.mean(f_err)
    std_f_err = np.std(f_err, ddof=1) / np.sqrt(len(f_err))

    mean_err = np.mean(test_err)
    std_err = np.std(test_err, ddof=1) / np.sqrt(len(test_err))

    print(f'==Averaged relative L2 error mean: {mean_err}, std error: {std_err}==\n'
          f'==Averaged equation error mean: {mean_f_err}, std error: {std_f_err}==')

# %% [markdown]
# # Load Config File

# %%
config_file = 'configs/custom/wave-0000.yaml'
config = load_config(config_file)
display(config)
# Out:
# {'data': {'name': 'Wave-0000',
#   'total_num': 1000,
#   'n_train': 900,
#   'n_test': 100,
#   'nx': 4096,
#   'nt': 100,
#   'sub': 32,
#   'sub_t': 1,
#   'c': 1.0},
#  'model': {'layers': [16, 24, 24, 32, 32],
#   'modes1': [15, 12, 9, 9],
#   'modes2': [15, 12, 9, 9],
#   'fc_dim': 128,
#   'activation': 'gelu'},
#  'train': {'batchsize': 20,
#   'epochs': 500,
#   'milestones': [150, 300, 450],
#   'base_lr': 0.001,
#   'scheduler_gamma': 0.5,
#   'ic_loss': 5.0,
#   'f_loss': 1.0,
#   'xy_loss': 10.0,
#   'save_dir': 'Wave',
#   'save_name': 'Wave-eqn.pt',
#   'ckpt': 'checkpoints/Wave/Wave-eqn.pt',
#   'ckpt_freq': 100},
#  'log': {'project': 'PINO-Wave', 'group': 'Wave-0000'},
#  'test': {'batchsize': 1, 'ckpt': 'checkpoints/Wave/Wave-eqn.pt'}}

# %% [markdown]
# # Parameters

# %%
Nsamples = config['data']['total_num']
N = config['data']['nx']
Nt0 = config['data']['nt']
c = config['data']['c']
sub_x = config['data']['sub']
sub_t = config['data']['sub_t']
Nx = N // sub_x
Nt = Nt0 // sub_t + 1
dim = 1
l = 0.1
L = 1.0
sigma = 0.2 #2.0
Nu = None # 2.0
dt = 1.0e-4
tend = 1.0
save_int = int(tend/dt/Nt)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Generate Random Fields

# %%
grf = GRF_Mattern(dim, N, length=L, nu=Nu, l=l, sigma=sigma, boundary="periodic", device=device)
U0 = grf.sample(Nsamples)

# %%
wave_eq = WaveEq1D(Nx=N, c=c, dt=dt, device=device)
U = vmap(wave_eq.wave_driver, in_dims=(0, None))(U0, save_int)

# %%
a = U0.cpu().float()
u = U.cpu().float()

display(u.shape,a.shape)
# Out:
# torch.Size([1000, 102, 4096])
# torch.Size([1000, 4096])

# %%
from train_utils.datasets import DataLoader1D

# %%
dataset = DataLoader1D(a, u, config['data']['nx'], config['data']['nt'], config['data']['sub'], config['data']['sub_t'])
train_loader = dataset.make_loader(config['data']['n_train'], config['train']['batchsize'], start=0, train=True)
test_loader = dataset.make_loader(config['data']['n_test'], config['test']['batchsize'], start=config['data']['n_train'], train=False)

# %%
log = False
model = FNN2d(modes1=config['model']['modes1'],
                  modes2=config['model']['modes2'],
                  fc_dim=config['model']['fc_dim'],
                  layers=config['model']['layers'],
                  activation=config['model']['activation']).to(device)

optimizer = Adam(model.parameters(), betas=(0.9, 0.999),lr=config['train']['base_lr'])
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer,
                                                 milestones=config['train']['milestones'],
                                                 gamma=config['train']['scheduler_gamma'])

# %% [markdown]
# # Load from checkpoint

# %%
load_checkpoint(model, ckpt_path=config['train']['ckpt'], optimizer=None)
# Out:
# Traceback (most recent call last):
#   File "/homes/iws/malali/cse481m-venv/PINO-apps/train_utils/utils.py", line 12, in load_checkpoint
#     ckpt = torch.load(ckpt_path, map_location=device)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/homes/iws/malali/cse481m-venv/lib64/python3.12/site-packages/torch/serialization.py", line 1530, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/homes/iws/malali/cse481m-venv/lib64/python3.12/site-packages/torch/serialization.py", line 795, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/homes/iws/malali/cse481m-venv/lib64/python3.12/site-packages/torch/serialization.py", line 776, in __init__
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoints/Wave/Wave-eqn.pt'

# %% [markdown]
# # Train the Model

# %%
train_wave(model,
           train_loader,
           optimizer,
           scheduler,
           config,
           rank=0,
           log=log,
           project=config['log']['project'],
           group=config['log']['group'])
# Out:
# Epoch 0, train loss: 10.37962 train f error: 0.27785; data l2 error: 1.00654; train ic error: 0.32749:   0%|          | 1/500 [00:02<18:01,  2.17s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_0.pt
# Epoch 100, train loss: 0.17232 train f error: 0.05615; data l2 error: 0.01162; train ic error: 0.00005:  20%|██        | 101/500 [02:35<10:17,  1.55s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_100.pt
# Epoch 200, train loss: 0.12375 train f error: 0.06240; data l2 error: 0.00613; train ic error: 0.00002:  40%|████      | 201/500 [05:10<07:40,  1.54s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_200.pt
# Epoch 300, train loss: 0.10123 train f error: 0.06513; data l2 error: 0.00361; train ic error: 0.00001:  60%|██████    | 301/500 [07:44<05:07,  1.54s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_300.pt
# ...

# %% [markdown]
# # Evaluate on Test Data

# %%
eval_wave(model, test_loader, config, device)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 210.19it/s]
# ==Averaged relative L2 error mean: 0.0018903520796447993, std error: 5.0873672682884525e-05==
# ==Averaged equation error mean: 0.07021932440809905, std error: 0.0034214543682788796==

# %%
eval_wave(model, test_loader, config, device)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 214.29it/s]
# ==Averaged relative L2 error mean: 0.0010572797025088221, std error: 2.361177358062839e-05==
# ==Averaged equation error mean: 0.07492405518889428, std error: 0.0036507779411330266==

# %%
# =============================================================================
# Resolution Invariance Test
# -----------------------------------------------------------------------------
# The PINO/FNO model was trained at Nx = N // sub = 128. Because the FNO uses
# a fixed number of Fourier modes (modes1/2) instead of grid-tied weights, the
# SAME checkpoint can be evaluated at any resolution Nx s.t. Nx//2 + 1 >= max(modes2).
# Here max(modes2) = 15, so we need Nx >= 28.
#
# We sweep sub_x over values that give:
#   Nx_eval in [64, 128, 256, 512, 1024]   (training res = 128)
# and record:
#   - rel L2 error  vs the high-res ground truth
#   - PINO equation residual (FFT-based wave-eq residual)
# =============================================================================

import matplotlib.pyplot as plt

n_train = config['data']['n_train']
n_test  = config['data']['n_test']
test_bs = config['test']['batchsize']

sub_x_list = [128, 64, 32, 16, 8, 4, 2, 1]   # -> Nx = 32, 64, 128, 256, 512, 1024, 2048, 4096

results = []
for sub_x in sub_x_list:
    Nx_eval = N // sub_x
    Nt_eval = Nt0 // sub_t + 1

    ds = DataLoader1D(a, u,
                      nx=N, nt=Nt0,
                      sub=sub_x, sub_t=sub_t)
    test_loader_res = ds.make_loader(n_test, test_bs,
                                     start=n_train, train=False)

    print(f"\n--- Evaluating at Nx={Nx_eval}, Nt={Nt_eval} (sub_x={sub_x}) ---")

    model.eval()
    myloss = LpLoss(size_average=True)
    test_err, f_err = [], []
    with torch.no_grad():
        for x, y in test_loader_res:
            x, y = x.to(device), y.to(device)
            out = model(x).reshape(y.shape)
            test_err.append(myloss(out, y).item())
            _, f_loss = PINO_loss_wave(out, x[:, 0, :, 0], c=c)
            f_err.append(f_loss.item())

    mean_err   = float(np.mean(test_err))
    mean_f_err = float(np.mean(f_err))
    print(f"  rel L2 error (data)  : {mean_err:.5f}")
    print(f"  equation residual    : {mean_f_err:.5e}")
    results.append((Nx_eval, mean_err, mean_f_err))

results = np.array(results)
print("\nresults shape:", results.shape, "  columns: [Nx, rel_L2, eq_residual]")
# Out:
# --- Evaluating at Nx=32, Nt=101 (sub_x=128) ---
#   rel L2 error (data)  : 0.00187
#   equation residual    : 7.02117e-02
#
# --- Evaluating at Nx=64, Nt=101 (sub_x=64) ---
#   rel L2 error (data)  : 0.00188
#   equation residual    : 7.02090e-02
#
# --- Evaluating at Nx=128, Nt=101 (sub_x=32) ---
#   rel L2 error (data)  : 0.00189
#   equation residual    : 7.02193e-02
#
# --- Evaluating at Nx=256, Nt=101 (sub_x=16) ---
#   rel L2 error (data)  : 0.00189
#   equation residual    : 7.03340e-02
#
# --- Evaluating at Nx=512, Nt=101 (sub_x=8) ---
#   rel L2 error (data)  : 0.00190
#   equation residual    : 7.15320e-02
#
# --- Evaluating at Nx=1024, Nt=101 (sub_x=4) ---
#   rel L2 error (data)  : 0.00190
#   equation residual    : 8.50389e-02
#
# --- Evaluating at Nx=2048, Nt=101 (sub_x=2) ---
#   rel L2 error (data)  : 0.00190
#   equation residual    : 1.93101e-01
#
# --- Evaluating at Nx=4096, Nt=101 (sub_x=1) ---
#   rel L2 error (data)  : 0.00190
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

train_nx = config['data']['nx'] // config['data']['sub']

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
ax.plot(results[:, 0], results[:, 1], 'o-', color='tab:blue')
ax.axvline(train_nx, color='gray', ls='--', label=f'Train resolution (Nx={train_nx})')
ax.set_xscale('log', base=2)
ax.set_xlabel('Spatial resolution Nx (eval)')
ax.set_ylabel('Relative L2 error')
ax.set_title('Prediction error vs resolution')
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(results[:, 0], results[:, 2], 's-', color='tab:orange')
ax.axvline(train_nx, color='gray', ls='--', label=f'Train resolution (Nx={train_nx})')
ax.set_xscale('log', base=2)
ax.set_yscale('log')
ax.set_xlabel('Spatial resolution Nx (eval)')
ax.set_ylabel('PDE equation residual')
ax.set_title('Physics residual vs resolution')
ax.legend()
ax.grid(True, alpha=0.3, which='both')

plt.suptitle('Resolution invariance — Wave 1D PINO', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Attempt 2

# %%
# =============================================================================
# Resolution Invariance Test  —  corrected to match the PINO paper's experiment
# =============================================================================
#
# The paper's Table 1 claim:
#   Train on LOW-resolution data + HIGH-resolution PDE loss,
#   then evaluate at 1×, 2×, 4× the DATA resolution.
#   The key finding is that L2 error stays flat — it does NOT explode at higher res.
#
# What the original code got wrong:
#   1. It swept to arbitrarily high resolutions (8×, 16× ... 128×) which is far
#      beyond what the paper tests, and extrapolates past the PDE training resolution.
#   2. The physics residual used raw MSE of FDM_Wave, which scales as O(Nx²)
#      because the spectral derivative wavenumbers grow with Nx. This makes the
#      residual look like it "explodes" even when the model is perfectly consistent
#      — it's just a units/scaling artifact, not a real physics failure.
#   3. The paper only reports L2 error. If you want to track physics residual, you
#      need to normalize it properly (divide by ||f||² or by Nx, Nt).
#
# What this cell does:
#   - Evaluates at training resolution (1×), 2×, and 4× (matching the paper).
#   - Also optionally shows 8× so you can see where things start to diverge.
#   - Reports NORMALIZED physics residual: mean |residual| / mean |u_tt|
#     so the number is dimensionless and comparable across resolutions.
#   - Compares FNO (data only) vs PINO (data + PDE loss) if two checkpoints exist.
#     If you only have one checkpoint, it just shows that one.
# =============================================================================

import numpy as np
import torch
import matplotlib.pyplot as plt
from train_utils.losses import LpLoss
from train_utils.datasets import DataLoader1D

# ── helpers ──────────────────────────────────────────────────────────────────

def FDM_Wave_normalized(u, D=1.0, c=1.0):
    """
    Returns the normalized wave-equation residual:
        residual = (u_tt - c²·u_xx)
    but normalizes by the magnitude of u_tt so the result is dimensionless
    and comparable across resolutions.

    Returns:
        rel_residual  (scalar) = ||u_tt - c²·u_xx|| / (||u_tt|| + eps)
    """
    batchsize = u.size(0)
    nt = u.size(1)
    nx = u.size(2)
    dt = D / (nt - 1)

    # Spectral second derivative in x  (only up to the training k_max)
    # We cap wavenumbers at the training spatial resolution to avoid
    # penalizing the model for frequencies it was never trained on.
    k_max_train = (N // config['data']['sub']) // 2   # training k_max
    k_max = min(nx // 2, k_max_train)                 # cap at training bandwidth

    u_h = torch.fft.fft(u, dim=2)
    k_x = torch.cat([
        torch.arange(0,  k_max,  device=u.device),
        torch.arange(-k_max, 0, device=u.device),
    ], dim=0)
    # Zero out super-training-resolution modes (model has no info there)
    mask = torch.zeros(nx, device=u.device)
    mask[:k_max] = 1.0
    mask[nx - k_max:] = 1.0
    u_h_filtered = u_h * mask.reshape(1, 1, nx)

    k_full = torch.cat([
        torch.arange(0, nx // 2, device=u.device),
        torch.arange(-nx // 2, 0, device=u.device),
    ], 0).reshape(1, 1, nx)
    uxx_h = -(2 * np.pi * k_full) ** 2 * u_h_filtered
    uxx = torch.fft.irfft(uxx_h[:, :, :nx // 2 + 1], dim=2, n=nx)

    # Finite difference second derivative in t
    utt = (u[:, 2:, :] - 2.0 * u[:, 1:-1, :] + u[:, :-2, :]) / (dt ** 2)
    uxx_interior = uxx[:, 1:-1, :]

    residual = utt - c ** 2 * uxx_interior

    # Normalize so the metric is dimensionless
    norm_utt = utt.abs().mean().clamp(min=1e-8)
    rel_res = residual.abs().mean() / norm_utt
    return rel_res.item()


def evaluate_at_resolution(model, a, u_full, sub_x_eval, config, device, n_train, n_test, test_bs):
    """
    Evaluate model at a given spatial subsampling factor sub_x_eval.
    Returns (mean_rel_L2, mean_normalized_physics_residual).
    """
    N_full   = config['data']['nx']    # full spatial size
    Nt0_full = config['data']['nt']    # full temporal size
    sub_t    = config['data']['sub_t']
    c        = config['data']['c']

    ds = DataLoader1D(a, u_full, nx=N_full, nt=Nt0_full, sub=sub_x_eval, sub_t=sub_t)
    loader = ds.make_loader(n_test, test_bs, start=n_train, train=False)

    myloss = LpLoss(size_average=True)
    model.eval()
    l2_errs, phys_errs = [], []

    with torch.no_grad():
        for x_batch, y_batch in loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            pred = model(x_batch).reshape(y_batch.shape)

            l2_errs.append(myloss(pred, y_batch).item())
            phys_errs.append(FDM_Wave_normalized(pred, D=1.0, c=c))

    return float(np.mean(l2_errs)), float(np.mean(phys_errs))


# ── experiment config ────────────────────────────────────────────────────────

n_train  = config['data']['n_train']
n_test   = config['data']['n_test']
test_bs  = config['test']['batchsize']

# Training spatial resolution
sub_x_train = config['data']['sub']
Nx_train    = N // sub_x_train
print(f"Training resolution: Nx={Nx_train}  (sub_x={sub_x_train})")

# Evaluate at 1×, 2×, 4×, 8× the training data resolution
# (paper only goes to 4×; we add 8× to show where it starts degrading)
multipliers  = [1, 2, 4, 8]
# sub_x needed to get Nx = multiplier × Nx_train:
#   Nx_eval = N // sub_x_eval  =>  sub_x_eval = N // (multiplier * Nx_train) = sub_x_train // multiplier
# (only valid while sub_x_eval >= 1)
sub_x_evals = []
labels       = []
for m in multipliers:
    s = sub_x_train // m
    if s >= 1:
        sub_x_evals.append(s)
        labels.append(f'{m}× ({N // s})')

print(f"Evaluating at sub_x values: {sub_x_evals}")
print(f"Corresponding Nx values:    {[N // s for s in sub_x_evals]}")
print()

# ── sweep ────────────────────────────────────────────────────────────────────

results = []   # (Nx, rel_L2, norm_phys_res)

for sub_x_eval, lbl in zip(sub_x_evals, labels):
    Nx_eval = N // sub_x_eval
    print(f"  Evaluating {lbl} resolution (Nx={Nx_eval}) ...", end=" ", flush=True)
    l2, phys = evaluate_at_resolution(
        model, a, u, sub_x_eval, config, device, n_train, n_test, test_bs
    )
    print(f"L2={l2*100:.4f}%, Phys={phys:.6f}")
    results.append((Nx_eval, l2, phys))

results = np.array(results)
Nx_vals   = results[:, 0]
l2_vals   = results[:, 1]
phys_vals = results[:, 2]

# ── plot ─────────────────────────────────────────────────────────────────────

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# Panel 1: Relative L2 error
ax = axes[0]
ax.plot(Nx_vals, l2_vals * 100, 'o-', color='tab:blue', linewidth=2, markersize=8)
ax.axvline(Nx_train, color='gray', ls='--', alpha=0.5, label=f'Train res. (Nx={Nx_train})')

ax.set_xscale('log', base=2)
ax.set_xticks(Nx_vals)
ax.get_xaxis().set_major_formatter(plt.ScalarFormatter())
ax.set_xlabel('Spatial resolution $N_x$')
ax.set_ylabel('Relative $L^2$ error (%)')
ax.set_title('Prediction Error vs. Resolution (Rel L2%)')
ax.grid(True, alpha=0.2)
ax.legend()

# Panel 2: Normalized physics residual
ax = axes[1]
ax.plot(Nx_vals, phys_vals, 's-', color='tab:orange', linewidth=2, markersize=8)
ax.axvline(Nx_train, color='gray', ls='--', alpha=0.5, label=f'Train res. (Nx={Nx_train})')

ax.ticklabel_format(useOffset=False, style='plain', axis='y') 
# Optional: Set the Y-limits manually so you can see how "flat" it is 
# (e.g., from 0 to 0.05 or just around the value)
buffer = 0.005
ax.set_ylim(min(phys_vals) - buffer, max(phys_vals) + buffer)

ax.set_xscale('log', base=2)
ax.set_xticks(Nx_vals)
ax.get_xaxis().set_major_formatter(plt.ScalarFormatter())
ax.set_xlabel('Spatial resolution $N_x$')
ax.set_ylabel('Normalized Physics Residual\n$||u_{tt} - c^2 u_{xx}|| / ||u_{tt}||$')
ax.set_title('Normalized Physics Residual vs Resolution')
ax.grid(True, alpha=0.2)
ax.legend()

plt.suptitle(
    f'Resolution Invariance — Wave 1D PINO\n'
    f'(Train Nx={Nx_train}; physics residual capped at training bandwidth)',
    y=1.03
)
plt.tight_layout()
plt.show()

# ── summary table ─────────────────────────────────────────────────────────────

print("\n" + "="*65)
print(f"{'Resolution':>15} | {'Rel L2 (%)':>15} | {'Norm Phys Res':>15}")
print("-" * 65)
for (nx_v, l2_v, ph_v) in results:
    mult = int(nx_v // Nx_train)
    label = f"{mult}x ({int(nx_v)})"
    marker = " [TRAIN RES]" if int(nx_v) == Nx_train else ""
    # Printing with higher precision (4 decimal places for percent)
    print(f"{label:>15} | {l2_v*100:>14.4f}% | {ph_v:>15.6f} {marker}")
print("="*65)

print(
    "\nPaper claim: L2 error should stay roughly flat from 1× to 4×.\n"
    "If PINO was trained WITH physics loss, the table should show minimal\n"
    "increase. If trained WITHOUT (pure FNO/data), error typically jumps at 2-4×.\n"
    "The normalized physics residual should also be stable if the model respects\n"
    "the PDE at the modes it was trained on."
)
# Out:
# Training resolution: Nx=128  (sub_x=32)
# Evaluating at sub_x values: [32, 16, 8, 4]
# Corresponding Nx values:    [128, 256, 512, 1024]
#
#   Evaluating 1× (128) resolution (Nx=128) ... L2=0.1890%, Phys=0.021705
#   Evaluating 2× (256) resolution (Nx=256) ... L2=0.1894%, Phys=0.021705
#   Evaluating 4× (512) resolution (Nx=512) ... L2=0.1895%, Phys=0.021705
#   Evaluating 8× (1024) resolution (Nx=1024) ... L2=0.1896%, Phys=0.021705
# ...
#      Resolution |      Rel L2 (%) |   Norm Phys Res
# -----------------------------------------------------------------
#        1x (128) |         0.1890% |        0.021705  [TRAIN RES]
#        2x (256) |         0.1894% |        0.021705
#        4x (512) |         0.1895% |        0.021705
#       8x (1024) |         0.1896% |        0.021705
# ...
#
# Paper claim: L2 error should stay roughly flat from 1× to 4×.
# If PINO was trained WITH physics loss, the table should show minimal
# ...

# %% [markdown]
# Attempt 3

# %%
# =============================================================================
# PINO Multi-Resolution Experiment
# -----------------------------------------------------------------------------
# Goal: replicate the spirit of the original resolution sweep (sub_x_list sweep
#       producing Nx = 32 → 4096) but fix it to match the PINO paper's actual
#       experimental design.
#
# What the original code did wrong:
#   1. Trained with data AND PDE loss at the SAME resolution. The paper's key
#      claim is that you train with data at low-res but PDE loss at HIGH-res.
#      That's what gives you robust super-resolution at eval time.
#   2. The physics residual (MSE of FDM_Wave) scales as O(1/Nx^2) because dt and
#      the absolute magnitudes of utt shrink as the grid gets finer — so even a
#      "perfect" model would look better at higher Nx. We fix this by normalizing.
#
# What this cell does:
#   Step 1 — PINO training: data at 1× resolution, PDE loss upsampled to 16×.
#            This is the paper's recipe extended to 16× so the model "knows"
#            about all the frequencies we're about to test.
#   Step 2 — Resolution sweep: evaluate the trained model at 1×, 2×, 4×, 8×,
#            16× (matching the original code's ambition) and report both:
#              - relative L2 error  (same as the original code)
#              - NORMALIZED physics residual: divide raw MSE by (dt^2 * Nx * Nt)
#                so the number is dimensionless and resolution-comparable.
#   Step 3 — Plot both metrics side by side.
#
# Assumptions (matching your existing notebook):
#   - `a`, `u`, `N`, `Nt0`, `c`, `sub_t`, `device` are already defined.
#   - `config` is already loaded from the yaml.
#   - `FNN2d`, `Adam`, `DataLoader1D`, `LpLoss`, `save_checkpoint` are imported.
#   - `FDM_Wave` and `PINO_loss_wave` are defined as in your notebook.
# =============================================================================

import copy
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from train_utils.losses import LpLoss
from train_utils.datasets import DataLoader1D
from train_utils.utils import save_checkpoint


# ── 0. Configuration ──────────────────────────────────────────────────────────

# Data (low) resolution — use whatever sub is in your config
sub_x_data = config['data']['sub']        # e.g. 32  → Nx_data = N // 32
sub_t_data = config['data']['sub_t']

# PDE loss resolution — highest resolution we want to test at eval time
# The paper uses 4× the data res; we go to 16× to match the original sweep.
# sub_x_pde must divide N and satisfy sub_x_pde <= sub_x_data.
pde_multiplier = 16                        # train PDE loss at 16× data res
sub_x_pde = max(1, sub_x_data // pde_multiplier)

Nx_data = N // sub_x_data
Nx_pde  = N // sub_x_pde

print(f"Data resolution : Nx = {Nx_data}  (sub_x = {sub_x_data})")
print(f"PDE  resolution : Nx = {Nx_pde}   (sub_x = {sub_x_pde})  [{pde_multiplier}× data res]")
print(f"Temporal points : Nt = {Nt0 // sub_t_data + 1}")


# ── 1. Modified training loop with high-res PDE loss ─────────────────────────
#
# The existing train_wave function evaluates PDE loss on the same grid as the
# data.  We need a second loader at the PDE resolution to supply initial
# conditions so the model can be queried at that finer grid and the wave
# residual computed there.
#
# Concretely, each training iteration:
#   a) Forward pass on low-res batch  → data loss + low-res PDE loss
#   b) Forward pass on high-res batch (same IC samples, finer grid) → high-res PDE loss
#   Total loss = data_loss * w_data + ic_loss * w_ic + pde_loss_highres * w_f

def train_wave_multires(model,
                        train_loader_data,   # low-res data batches (x, y)
                        train_loader_pde,    # high-res batches (x_hi, y_hi) — y_hi not used
                        optimizer,
                        scheduler,
                        config,
                        epochs=None,
                        device='cpu'):
    """
    Train PINO with data loss at data resolution and PDE loss at pde resolution.
    train_loader_pde can be longer or shorter than train_loader_data; we cycle it.
    """
    data_weight = config['train']['xy_loss']
    f_weight    = config['train']['f_loss']
    ic_weight   = config['train']['ic_loss']
    c_val       = config['data']['c']
    n_epochs    = epochs if epochs is not None else config['train']['epochs']
    myloss      = LpLoss(size_average=True)

    # Make the high-res loader an infinite iterator so lengths don't have to match
    def cycle(loader):
        while True:
            for batch in loader:
                yield batch

    pde_iter = cycle(train_loader_pde)

    pbar = tqdm(range(n_epochs), dynamic_ncols=True, smoothing=0.1)
    for e in pbar:
        model.train()
        epoch_data_l2 = 0.0
        epoch_pde     = 0.0
        epoch_ic      = 0.0
        epoch_total   = 0.0

        for x_lo, y_lo in train_loader_data:
            x_lo, y_lo = x_lo.to(device), y_lo.to(device)

            # ── (a) data loss at training resolution ──────────────────────
            out_lo    = model(x_lo).reshape(y_lo.shape)
            data_loss = myloss(out_lo, y_lo)

            # ── (b) PDE loss at high resolution ───────────────────────────
            # x_hi carries the same initial conditions on a finer grid;
            # we only need the IC (first time row) from it.
            x_hi, _ = next(pde_iter)
            x_hi    = x_hi.to(device)
            out_hi  = model(x_hi).reshape(x_hi.shape[0],
                                          x_hi.shape[1],   # Nt
                                          x_hi.shape[2])   # Nx_pde
            # IC at high res: x_hi[:, 0, :, 0]  (same shape convention as low-res)
            loss_ic_hi, loss_f_hi = PINO_loss_wave(out_hi, x_hi[:, 0, :, 0], c=c_val)

            total_loss = (data_loss   * data_weight
                        + loss_ic_hi * ic_weight
                        + loss_f_hi  * f_weight)

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            epoch_data_l2 += data_loss.item()
            epoch_pde     += loss_f_hi.item()
            epoch_ic      += loss_ic_hi.item()
            epoch_total   += total_loss.item()

        n = len(train_loader_data)
        scheduler.step()
        pbar.set_description(
            f'Ep {e}  loss={epoch_total/n:.4f}  '
            f'data={epoch_data_l2/n:.4f}  '
            f'pde(hi)={epoch_pde/n:.5f}  '
            f'ic={epoch_ic/n:.5f}'
        )

    print('Training done.')


# ── 2. Build data loaders ─────────────────────────────────────────────────────

n_train = config['data']['n_train']
n_test  = config['data']['n_test']
bs      = config['train']['batchsize']
bs_test = config['test']['batchsize']

# Low-res loader (data + low-res PDE during old training, now only data loss)
ds_data        = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_data, sub_t=sub_t_data)
train_loader   = ds_data.make_loader(n_train, bs,      start=0,       train=True)
test_loader    = ds_data.make_loader(n_test,  bs_test, start=n_train, train=False)

# High-res loader for PDE loss (same samples, finer grid, ground truth ignored)
ds_pde         = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_pde, sub_t=sub_t_data)
train_loader_pde = ds_pde.make_loader(n_train, bs, start=0, train=True)


# ── 3. Initialise a fresh model and train ────────────────────────────────────

model_pino = FNN2d(
    modes1=config['model']['modes1'],
    modes2=config['model']['modes2'],
    fc_dim=config['model']['fc_dim'],
    layers=config['model']['layers'],
    activation=config['model']['activation'],
).to(device)

optimizer_pino = Adam(model_pino.parameters(), betas=(0.9, 0.999),
                      lr=config['train']['base_lr'])
scheduler_pino = torch.optim.lr_scheduler.MultiStepLR(
    optimizer_pino,
    milestones=config['train']['milestones'],
    gamma=config['train']['scheduler_gamma'],
)

print(f"\n{'='*60}")
print("Training PINO (data @ 1×, PDE loss @ 16×) ...")
print(f"{'='*60}\n")

train_wave_multires(
    model_pino,
    train_loader,
    train_loader_pde,
    optimizer_pino,
    scheduler_pino,
    config,
    device=device,
)

# Optionally save
save_checkpoint(config['train']['save_dir'],
                config['train']['save_name'].replace('.pt', '_multires16x.pt'),
                model_pino, optimizer_pino)


# ── 4. Resolution sweep evaluation ───────────────────────────────────────────
#
# We sweep the SAME multipliers as the original code (up to 16×).
# Physics residual fix: divide raw MSE by (1/Nx / 1/Nt)^scale so it's
# dimensionless.  The cleanest normalization is:
#
#   normalized_residual = sqrt(MSE(Du)) / (||u||_rms / T)
#
# i.e. the RMS residual divided by the RMS solution scaled by the time window.
# This makes the number ≈ 1 for a random model and → 0 for a perfect one,
# regardless of grid size.

def compute_normalized_physics_residual(out, c_val):
    """
    Returns a dimensionless physics residual:
        RMS( u_tt - c²·u_xx ) / RMS( u_tt )
    We use u_tt as the normalizer because it has the same physical dimensions
    as the residual, and it captures the scale of the second-order dynamics
    without referencing ground truth.
    """
    Du = FDM_Wave(out, D=1.0, c=c_val)          # shape (B, Nt-2, Nx)
    nt = out.size(1)
    dt = 1.0 / (nt - 1)
    utt = (out[:, 2:, :] - 2.0 * out[:, 1:-1, :] + out[:, :-2, :]) / (dt ** 2)

    rms_res = Du.pow(2).mean().sqrt()
    rms_utt = utt.pow(2).mean().sqrt().clamp(min=1e-8)
    return (rms_res / rms_utt).item()


# Multipliers to test: [1, 2, 4, 8, 16]  → sub_x = [sub_x_data, /2, /4, /8, /16]
eval_multipliers = [1, 2, 4, 8, 16]
results = []   # (Nx, rel_L2, norm_phys)

myloss = LpLoss(size_average=True)

for mult in eval_multipliers:
    sub_x_eval = max(1, sub_x_data // mult)
    if N // sub_x_eval < 2 * config['model']['modes2']:
        # FNO needs Nx >= 2 * modes to run — skip if too small
        print(f"Skipping {mult}× (Nx={N//sub_x_eval} < 2×modes={2*config['model']['modes2']})")
        continue

    Nx_eval = N // sub_x_eval
    print(f"\n--- Evaluating at {mult}× (Nx={Nx_eval}, sub_x={sub_x_eval}) ---",
          end=" ", flush=True)

    ds_eval   = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_eval, sub_t=sub_t_data)
    loader_ev = ds_eval.make_loader(n_test, bs_test, start=n_train, train=False)

    l2_list, phys_list = [], []
    model_pino.eval()
    with torch.no_grad():
        for x_ev, y_ev in loader_ev:
            x_ev, y_ev = x_ev.to(device), y_ev.to(device)
            out_ev = model_pino(x_ev).reshape(y_ev.shape)

            l2_list.append(myloss(out_ev, y_ev).item())
            phys_list.append(compute_normalized_physics_residual(out_ev, c))

    mean_l2   = float(np.mean(l2_list))
    mean_phys = float(np.mean(phys_list))
    print(f"rel L2 = {mean_l2:.4f},  norm phys = {mean_phys:.4e}")
    results.append((Nx_eval, mult, mean_l2, mean_phys))


# ── 5. Plot ───────────────────────────────────────────────────────────────────

results = np.array(results)   # columns: Nx, mult, rel_L2, norm_phys
Nx_vals   = results[:, 0]
mult_vals = results[:, 1]
l2_vals   = results[:, 2]
phys_vals = results[:, 3]

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# -- Panel 1: Relative L2 error
ax = axes[0]
ax.plot(mult_vals, l2_vals * 100, 'o-', color='tab:blue', lw=2, ms=8)
ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
for m, l2 in zip(mult_vals, l2_vals):
    ax.annotate(f'{l2*100:.2f}%', (m, l2*100),
                textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
ax.set_xticks(mult_vals)
ax.set_xticklabels([f'{int(m)}×\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
ax.set_xlabel('Eval resolution (× training data resolution)')
ax.set_ylabel('Relative $L^2$ error (%)')
ax.set_title('Prediction error vs resolution\n(should stay flat for PINO)')
ax.legend()
ax.grid(True, alpha=0.3)

# -- Panel 2: Normalized physics residual
ax = axes[1]
ax.plot(mult_vals, phys_vals, 's-', color='tab:orange', lw=2, ms=8)
ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
for m, ph in zip(mult_vals, phys_vals):
    ax.annotate(f'{ph:.3f}', (m, ph),
                textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
ax.set_xticks(mult_vals)
ax.set_xticklabels([f'{int(m)}×\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
ax.set_xlabel('Eval resolution (× training data resolution)')
ax.set_ylabel('Norm. physics residual\n$\\sqrt{\\mathrm{MSE}(u_{tt} - c^2 u_{xx})} / \\sqrt{\\mathrm{MSE}(u_{tt})}$')
ax.set_title('Physics residual vs resolution\n(normalized: dimensionless across grids)')
ax.legend()
ax.grid(True, alpha=0.3)

plt.suptitle(
    f'PINO Wave 1D — Resolution Invariance\n'
    f'Data @ Nx={Nx_data} (1×),  PDE loss @ Nx={Nx_pde} ({pde_multiplier}×)',
    y=1.03
)
plt.tight_layout()
plt.show()

# ── 6. Summary table ──────────────────────────────────────────────────────────

print(f"\n{'='*58}")
print(f"  {'Mult':>4}  {'Nx':>6}  {'Rel L2 (%)':>12}  {'Norm Phys Res':>15}")
print(f"{'='*58}")
for nx, mult, l2, phys in results:
    tag = " ← train" if int(mult) == 1 else (
          f" ← PDE train" if int(nx) == Nx_pde else "")
    print(f"  {int(mult):>4}×  {int(nx):>6}  {l2*100:>12.3f}%  {phys:>15.4e}{tag}")
print(f"{'='*58}")
print(
    "\nInterpretation:"
    "\n  L2 error   — should be roughly flat (paper's claim). If it rises"
    "\n               steeply, the model isn't generalizing to unseen frequencies."
    "\n  Norm phys  — RMS residual / RMS(u_tt). A value near 0 means the model"
    "\n               satisfies the wave equation at that resolution. Because we"
    "\n               divide by u_tt, this is comparable across all Nx values."
    "\n               Training PDE loss at 16× should keep this small up to 16×."
)
# Out:
# Data resolution : Nx = 128  (sub_x = 32)
# PDE  resolution : Nx = 2048   (sub_x = 2)  [16× data res]
# Temporal points : Nt = 101
#
# ...
# Training PINO (data @ 1×, PDE loss @ 16×) ...
# ...
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[35], line 196
#     193 print("Training PINO (data @ 1×, PDE loss @ 16×) ...")
#     194 print(f"{'='*60}\n")
# --> 196 train_wave_multires(
#     197     model_pino,
#     198     train_loader,
#     199     train_loader_pde,
#     200     optimizer_pino,
#     201     scheduler_pino,
#     202     config,
#     203     device=device,
#     204 )
#     206 # Optionally save
#     207 save_checkpoint(config['train']['save_dir'],
#     208                 config['train']['save_name'].replace('.pt', '_multires16x.pt'),
#     209                 model_pino, optimizer_pino)
#
# ...

# %% [markdown]
# Attempt 4

# %%
# =============================================================================
# PINO Multi-Resolution Experiment — OOM-fixed version
# -----------------------------------------------------------------------------
# Fixes applied vs previous version:
#
#   1. DEVICE: explicitly use cuda:2 (empty GPU) instead of the default device
#      which was cuda:1 (already ~10GB used). You can change EXPERIMENT_DEVICE
#      below if needed.
#
#   2. OOM from high-res forward pass: Nx=2048 × Nt=101 × batch_size blows up.
#      Fix: use a separate (smaller) batch size for the high-res PDE pass.
#      The high-res loader only needs initial conditions — no ground truth —
#      so we can afford to cut the batch down to 1–4 samples.
#      Rule of thumb: if Nx_pde = k × Nx_data, use bs_pde ≈ bs_data / k.
#
#   3. torch.cuda.empty_cache() call before training to free any lingering
#      allocations from earlier notebook cells.
# =============================================================================

import copy
import os
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from train_utils.losses import LpLoss
from train_utils.datasets import DataLoader1D
from train_utils.utils import save_checkpoint

# ── 0. Pick the device for THIS experiment ───────────────────────────────────
# GPU 2 is empty (3 MiB used). GPU 1 is nearly full — don't use it here.
EXPERIMENT_DEVICE = torch.device('cuda:2')   # ← change to 'cuda:0' if you prefer

torch.cuda.empty_cache()
print(f"Running experiment on: {EXPERIMENT_DEVICE}")
print(f"  Free memory: {torch.cuda.mem_get_info(EXPERIMENT_DEVICE)[0] / 1e9:.2f} GB")

# ── 1. Resolution config ──────────────────────────────────────────────────────

sub_x_data = config['data']['sub']    # e.g. 32  → Nx_data = N // 32 = 128
sub_t_data = config['data']['sub_t']

# How many times finer should the PDE loss resolution be vs the data?
# 16× at Nx=2048 is the OOM culprit when batch_size is large.
# We keep pde_multiplier=16 but reduce the batch size proportionally.
pde_multiplier = 16

sub_x_pde = max(1, sub_x_data // pde_multiplier) 

Nx_data = N // sub_x_data
Nx_pde  = N // sub_x_pde # Nx_pde == pde_multiplier * Nx_data

# Batch sizes
bs_data = config['train']['batchsize']          # e.g. 8 — used for data loss
# Scale batch size inversely with spatial resolution to keep memory flat.
# Memory scales as Nx × Nt × channels, so bs_pde = bs_data // pde_multiplier.
# Clamp to at least 1.
bs_pde  = max(1, bs_data // pde_multiplier)

# If you have memory headroom and want a less noisy PDE gradient,
# you can manually set bs_pde higher — just don't exceed what fits in VRAM.
# bs_pde = 2  # ← optional override

print(f"\nData resolution : Nx = {Nx_data}  (sub_x = {sub_x_data}, batch = {bs_data})")
print(f"PDE  resolution : Nx = {Nx_pde}  (sub_x = {sub_x_pde}, batch = {bs_pde})  [{pde_multiplier}× data res]")
print(f"Temporal points : Nt = {Nt0 // sub_t_data + 1}")
print(f"\nEstimated peak tensor size for high-res pass: "
      f"{bs_pde * (Nt0//sub_t_data+1) * Nx_pde * 4 / 1e6:.1f} MB  "
      f"(before FNO intermediate channels)")

# ── 2. Modified training loop ─────────────────────────────────────────────────

def train_wave_multires(model,
                        train_loader_data,
                        train_loader_pde,
                        optimizer,
                        scheduler,
                        config,
                        experiment_device,
                        epochs=None):
    data_weight = config['train']['xy_loss']
    f_weight    = config['train']['f_loss']
    ic_weight   = config['train']['ic_loss']
    c_val       = config['data']['c']
    n_epochs    = epochs if epochs is not None else config['train']['epochs']
    myloss      = LpLoss(size_average=True)

    def cycle(loader):
        while True:
            for batch in loader:
                yield batch

    pde_iter = cycle(train_loader_pde)

    pbar = tqdm(range(n_epochs), dynamic_ncols=True, smoothing=0.1)
    for e in pbar:
        model.train()
        epoch_data_l2 = 0.0
        epoch_pde     = 0.0
        epoch_ic      = 0.0
        epoch_total   = 0.0

        for x_lo, y_lo in train_loader_data:
            x_lo = x_lo.to(experiment_device)
            y_lo = y_lo.to(experiment_device)

            # (a) Data loss at training resolution
            out_lo    = model(x_lo).reshape(y_lo.shape)
            data_loss = myloss(out_lo, y_lo)

            # (b) PDE loss at high resolution — small batch, no ground truth needed
            x_hi, _ = next(pde_iter)
            x_hi = x_hi.to(experiment_device)

            out_hi = model(x_hi).reshape(x_hi.shape[0],
                                         x_hi.shape[1],   # Nt
                                         x_hi.shape[2])   # Nx_pde
            loss_ic_hi, loss_f_hi = PINO_loss_wave(out_hi, x_hi[:, 0, :, 0], c=c_val)

            total_loss = (data_loss   * data_weight
                        + loss_ic_hi * ic_weight
                        + loss_f_hi  * f_weight)

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            # Free the high-res output immediately — don't let it linger
            del out_hi, x_hi, loss_ic_hi, loss_f_hi

            epoch_data_l2 += data_loss.item()
            epoch_pde     += total_loss.item() - data_loss.item() * data_weight
            epoch_ic      += 0.0   # absorbed into pde line above for brevity
            epoch_total   += total_loss.item()

        n = len(train_loader_data)
        scheduler.step()
        pbar.set_description(
            f'Ep {e}  total={epoch_total/n:.4f}  '
            f'data={epoch_data_l2/n:.4f}  '
            f'pde+ic(hi)={epoch_pde/n:.5f}'
        )

    print('Training done.')


# ── 3. Build loaders ──────────────────────────────────────────────────────────

n_train = config['data']['n_train']
n_test  = config['data']['n_test']
bs_test = config['test']['batchsize']

# Low-res: data + test
ds_data      = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_data, sub_t=sub_t_data)
train_loader = ds_data.make_loader(n_train, bs_data, start=0,       train=True)
test_loader  = ds_data.make_loader(n_test,  bs_test, start=n_train, train=False)

# High-res: PDE loss only — smaller batch
ds_pde           = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_pde, sub_t=sub_t_data)
train_loader_pde = ds_pde.make_loader(n_train, bs_pde, start=0, train=True)

# ── 4. Build model on the experiment device ───────────────────────────────────

model_pino = FNN2d(
    modes1=config['model']['modes1'],
    modes2=config['model']['modes2'],
    fc_dim=config['model']['fc_dim'],
    layers=config['model']['layers'],
    activation=config['model']['activation'],
).to(EXPERIMENT_DEVICE)

optimizer_pino = Adam(model_pino.parameters(), betas=(0.9, 0.999),
                      lr=config['train']['base_lr'])
scheduler_pino = torch.optim.lr_scheduler.MultiStepLR(
    optimizer_pino,
    milestones=config['train']['milestones'],
    gamma=config['train']['scheduler_gamma'],
)

print(f"\n{'='*60}")
print(f"Training PINO  (data @ {Nx_data}=1×,  PDE loss @ {Nx_pde}={pde_multiplier}×)")
print(f"  data batch={bs_data},  PDE batch={bs_pde}")
print(f"{'='*60}\n")

train_wave_multires(
    model_pino,
    train_loader,
    train_loader_pde,
    optimizer_pino,
    scheduler_pino,
    config,
    experiment_device=EXPERIMENT_DEVICE,
)

save_checkpoint(
    config['train']['save_dir'],
    config['train']['save_name'].replace('.pt', f'_multires{pde_multiplier}x.pt'),
    model_pino, optimizer_pino,
)

# ── 5. Resolution sweep ───────────────────────────────────────────────────────

def compute_normalized_physics_residual(out, c_val):
    """
    Dimensionless physics residual:  RMS(u_tt - c²·u_xx) / RMS(u_tt)
    This ratio is independent of grid spacing, so it's comparable across Nx.
    """
    Du  = FDM_Wave(out, D=1.0, c=c_val)
    nt  = out.size(1)
    dt  = 1.0 / (nt - 1)
    utt = (out[:, 2:, :] - 2.0 * out[:, 1:-1, :] + out[:, :-2, :]) / (dt ** 2)

    rms_res = Du.pow(2).mean().sqrt()
    rms_utt = utt.pow(2).mean().sqrt().clamp(min=1e-8)
    return (rms_res / rms_utt).item()


eval_multipliers = [1, 2, 4, 8, 16]
results = []
myloss  = LpLoss(size_average=True)

for mult in eval_multipliers:
    sub_x_eval = max(1, sub_x_data // mult)
    Nx_eval    = N // sub_x_eval

    if N // sub_x_eval < 2 * max(config['model']['modes2']):
        print(f"Skipping {mult}× (Nx={Nx_eval} < 2×modes)")
        continue

    print(f"\n--- {mult}× (Nx={Nx_eval}, sub_x={sub_x_eval}) ---", end=" ", flush=True)

    ds_ev    = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_eval, sub_t=sub_t_data)
    loader_ev = ds_ev.make_loader(n_test, bs_test, start=n_train, train=False)

    l2_list, phys_list = [], []
    model_pino.eval()
    with torch.no_grad():
        for x_ev, y_ev in loader_ev:
            x_ev = x_ev.to(EXPERIMENT_DEVICE)
            y_ev = y_ev.to(EXPERIMENT_DEVICE)
            out_ev = model_pino(x_ev).reshape(y_ev.shape)

            l2_list.append(myloss(out_ev, y_ev).item())
            phys_list.append(compute_normalized_physics_residual(out_ev, c))

    mean_l2   = float(np.mean(l2_list))
    mean_phys = float(np.mean(phys_list))
    print(f"rel L2 = {mean_l2:.4f},  norm phys = {mean_phys:.4e}")
    results.append((Nx_eval, mult, mean_l2, mean_phys))

# ── 6. Plot ───────────────────────────────────────────────────────────────────

results   = np.array(results)
Nx_vals   = results[:, 0]
mult_vals = results[:, 1]
l2_vals   = results[:, 2]
phys_vals = results[:, 3]

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
ax.plot(mult_vals, l2_vals * 100, 'o-', color='tab:blue', lw=2, ms=8)
ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
for m, l2, nx in zip(mult_vals, l2_vals, Nx_vals):
    ax.annotate(f'{l2*100:.2f}%', (m, l2*100),
                textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
ax.set_xticks(mult_vals)
ax.set_xticklabels([f'{int(m)}×\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
ax.set_xlabel('Eval resolution')
ax.set_ylabel('Relative $L^2$ error (%)')
ax.set_title('Prediction error vs resolution\n(flat = good: paper\'s claim)')
ax.legend(); ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(mult_vals, phys_vals, 's-', color='tab:orange', lw=2, ms=8)
ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
for m, ph, nx in zip(mult_vals, phys_vals, Nx_vals):
    ax.annotate(f'{ph:.3f}', (m, ph),
                textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
ax.set_xticks(mult_vals)
ax.set_xticklabels([f'{int(m)}×\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
ax.set_xlabel('Eval resolution')
ax.set_ylabel('Norm. physics residual\n$\\mathrm{RMS}(u_{tt}-c^2u_{xx})\\ /\\ \\mathrm{RMS}(u_{tt})$')
ax.set_title('Physics residual vs resolution\n(dimensionless, comparable across grids)')
ax.legend(); ax.grid(True, alpha=0.3)

plt.suptitle(
    f'PINO Wave 1D — Resolution Invariance\n'
    f'Data @ Nx={Nx_data} (1×),  PDE loss @ Nx={Nx_pde} ({pde_multiplier}×)',
    y=1.03,
)
plt.tight_layout()
plt.show()

# ── 7. Summary table ──────────────────────────────────────────────────────────

print(f"\n{'='*60}")
print(f"  {'Mult':>5}  {'Nx':>6}  {'Rel L2 (%)':>12}  {'Norm Phys Res':>15}")
print(f"{'='*60}")
for nx, mult, l2, phys in results:
    tag = " ← data train" if int(mult) == 1 else (
          " ← PDE train"  if int(nx)   == Nx_pde else "")
    print(f"  {int(mult):>4}×  {int(nx):>6}  {l2*100:>12.3f}%  {phys:>15.4e}{tag}")
print(f"{'='*60}")
print(
    "\nKey:"
    "\n  Rel L2       — flat across resolutions confirms PINO's resolution-invariance claim."
    "\n  Norm phys    — near 0 at all resolutions ≤ PDE training res confirms the model"
    "\n                 learned to respect the wave equation at those frequencies."
    "\n  Both metrics are expected to degrade beyond the PDE training resolution (>16×)."
)
# Out:
# Running experiment on: cuda:2
#   Free memory: 11.38 GB
#
# Data resolution : Nx = 128  (sub_x = 32, batch = 20)
# PDE  resolution : Nx = 2048  (sub_x = 2, batch = 1)  [16× data res]
# Temporal points : Nt = 101
#
# Estimated peak tensor size for high-res pass: 0.8 MB  (before FNO intermediate channels)
#
# ...
# Training PINO  (data @ 128=1×,  PDE loss @ 2048=16×)
#   data batch=20,  PDE batch=1
# ...
# Ep 499  total=0.1492  data=0.0027  pde+ic(hi)=0.12201: 100%|██████████| 500/500 [20:42<00:00,  2.48s/it]
# Training done.
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_multires16x.pt
#
# --- 1× (Nx=128, sub_x=32) ---
# rel L2 = 0.0026,  norm phys = 2.2553e-02
#
# --- 2× (Nx=256, sub_x=16) --- rel L2 = 0.0025,  norm phys = 2.2556e-02
#
# --- 4× (Nx=512, sub_x=8) --- rel L2 = 0.0025,  norm phys = 2.2632e-02
#
# --- 8× (Nx=1024, sub_x=4) --- rel L2 = 0.0025,  norm phys = 2.3930e-02
#
# --- 16× (Nx=2048, sub_x=2) --- rel L2 = 0.0025,  norm phys = 3.2458e-02
# ...

# %%
Nx = config['data']['nx'] // config['data']['sub']
Nt = config['data']['nt'] // config['data']['sub_t'] + 1
Ntest = config['data']['n_test']
model.eval()
test_x = np.zeros((Ntest,Nt,Nx,3))
preds_y = np.zeros((Ntest,Nt,Nx))
test_y = np.zeros((Ntest,Nt,Nx))
with torch.no_grad():
    for i, data in enumerate(test_loader):
        data_x, data_y = data
        data_x, data_y = data_x.to(device), data_y.to(device)
        pred_y = model(data_x).reshape(data_y.shape)
        test_x[i] = data_x.cpu().numpy()
        test_y[i] = data_y.cpu().numpy()
        preds_y[i] = pred_y.cpu().numpy()
#     data_loss = myloss(out, y)

# %%
key = 1
pred = preds_y[key]
true = test_y[key]


a = test_x[key]
Nt, Nx, _ = a.shape
u0 = a[0,:,0]
T = a[:,:,2]
X = a[:,:,1]
x = X[0]

# %%
plt.rcParams.update({'font.size': 11})

# %%
fig = plt.figure(figsize=(24,5))
plt.subplot(1,4,1)

plt.plot(x, u0)
plt.xlabel('$x$')
plt.ylabel('$u$')
plt.title('Intial Condition $u(x)$')
plt.xlim([0,1])
plt.tight_layout()

plt.subplot(1,4,2)
# plt.pcolor(XX,TT, S_test, cmap='jet')
plt.pcolormesh(X, T, true, cmap='jet', shading='gouraud')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title(f'Exact $u(x,t)$')
plt.tight_layout()
plt.axis('square')

plt.subplot(1,4,3)
# plt.pcolor(XX,TT, S_pred, cmap='jet')
plt.pcolormesh(X, T, pred, cmap='jet', shading='gouraud')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title(f'Predict $u(x,t)$')
plt.axis('square')

plt.tight_layout()

plt.subplot(1,4,4)
# plt.pcolor(XX,TT, S_pred - S_test, cmap='jet')
plt.pcolormesh(X, T, pred - true, cmap='jet', shading='gouraud')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title('Absolute error')
plt.tight_layout()
plt.axis('square')

plt.show()
# Out:
# <div id='5ce94ff1-84a9-452d-9d27-45e3c039ffd5'></div>

# %%
plt.show()

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
ax.plot(x, true[0], 'b-', label='Exact')
ax.plot(x, pred[0], 'r--', label='PINO Prediction')
ylim = plt.ylim()
xlim = [0, 1]
plt.tight_layout()



for i in range(Nt):
    ax.clear()
    ax.plot(x, true[i], 'b-', label='Exact')
    ax.plot(x, pred[i], 'r--', label='PINO Prediction')
    plt.ylim(ylim)
    plt.xlim(xlim)
    plt.xlabel(f'$x$')
    plt.ylabel(f'$u$')
    plt.title(f'Wave Equation')
    plt.legend(loc='lower right')
    plt.tight_layout()
    fig.canvas.draw()
# Out:
# <div id='6d690ee6-bf95-4ec9-b580-920f80ff26c0'></div>

# %% [markdown]
# # Save and Load Data

# %%
def save_data(data_path, test_x, test_y, preds_y):
    data_dir, data_filename = os.path.split(data_path)
    os.makedirs(data_dir, exist_ok=True)
    np.savez(data_path, test_x=test_x, test_y=test_y, preds_y=preds_y)

def load_data(data_path):
    data = np.load(data_path)
    test_x = data['test_x']
    test_y = data['test_y']
    preds_y = data['preds_y']
    return test_x, test_y, preds_y

# %%
data_dir = 'data/Wave1D'
data_filename = 'data.npz'
data_path = os.path.join(data_dir, data_filename)
# os.makedirs(data_dir, exist_ok=True)

# %%
save_data(data_path, test_x, test_y, preds_y)

# %%
test_x, test_y, preds_y = load_data(data_path)

# %%
def plot_predictions(key, test_x, test_y, preds_y, print_index=False, save_path=None, font_size=None):
    if font_size is not None:
        plt.rcParams.update({'font.size': font_size})
    pred = preds_y[key]
    true = test_y[key]


    a = test_x[key]
    Nt, Nx, _ = a.shape
    u0 = a[0,:,0]
    T = a[:,:,2]
    X = a[:,:,1]
    x = X[0]

    # Plot
    fig = plt.figure(figsize=(23,5))
    plt.subplot(1,4,1)

    plt.plot(x, u0)
    plt.xlabel('$x$')
    plt.ylabel('$u$')
    plt.title('Intial Condition $u(x)$')
    plt.xlim([0,1])
    plt.tight_layout()

    plt.subplot(1,4,2)
    # plt.pcolor(XX,TT, S_test, cmap='jet')
    plt.pcolormesh(X, T, true, cmap='jet', shading='gouraud')
    plt.colorbar()
    plt.xlabel('$x$')
    plt.ylabel('$t$')
    plt.title(f'Exact $u(x,t)$')
    plt.tight_layout()
    plt.axis('square')

    plt.subplot(1,4,3)
    # plt.pcolor(XX,TT, S_pred, cmap='jet')
    plt.pcolormesh(X, T, pred, cmap='jet', shading='gouraud')
    plt.colorbar()
    plt.xlabel('$x$')
    plt.ylabel('$t$')
    plt.title(f'Predict $u(x,t)$')
    plt.axis('square')

    plt.tight_layout()

    plt.subplot(1,4,4)
    # plt.pcolor(XX,TT, S_pred - S_test, cmap='jet')
    plt.pcolormesh(X, T, pred - true, cmap='jet', shading='gouraud')
    plt.colorbar()
    plt.xlabel('$x$')
    plt.ylabel('$t$')
    plt.title('Absolute Error')
    plt.tight_layout()
    plt.axis('square')

    if save_path is not None:
        plt.savefig(f'{save_path}.png', bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Movies

# %%
def generate_movie_1D(key, test_x, test_y, preds_y, plot_title='', movie_dir='', movie_name='movie.gif', frame_basename='movie', frame_ext='jpg', remove_frames=True, font_size=None):
    frame_files = []
    os.makedirs(movie_dir, exist_ok=True)

    if font_size is not None:
        plt.rcParams.update({'font.size': font_size})
    
    pred = preds_y[key]
    true = test_y[key]

    
    a = test_x[key]
    Nt, Nx, _ = a.shape
    u0 = a[0,:,0]
    T = a[:,:,2]
    X = a[:,:,1]
    x = X[0]
    t = T[:,0]

    fig = plt.figure(figsize=(6,5))
    ax = fig.add_subplot(111)
    plt.ion()

    fig.show()
    fig.canvas.draw()
    a = test_x[key]
    Nt, Nx, _ = a.shape
    u0 = a[0,:,0]
    T = a[:,:,2]
    X = a[:,:,1]
    x = X[0]
    ax.plot(x, true[0], 'b-', label='Exact')
    ax.plot(x, pred[0], 'r--', label='PINO Prediction')
    ylim = plt.ylim()
    xlim = [0, 1]
#     plt.xlim(xlim)
#     plt.xlabel(f'$x$')
#     plt.ylabel(f'$u$')
#     plt.title(f'{plot_title} $t={t[0]:.2f}$')
#     plt.legend(loc='lower right')
    plt.tight_layout()
    
    
    
    for i in range(Nt):
        ax.clear()
        ax.plot(x, true[i], 'b-', label='Exact')
        ax.plot(x, pred[i], 'r--', label='PINO Prediction')
        
        plt.xlabel(f'$x$')
        plt.ylabel(f'$u$')
        plt.title(f'{plot_title} $t={t[i]:.2f}$')
        plt.legend(loc='lower right')
        plt.ylim(ylim)
        plt.xlim(xlim)
        plt.tight_layout()
        fig.canvas.draw()
#         plt.show()
        if movie_dir:
            frame_path = os.path.join(movie_dir,f'{frame_basename}-{i:03}.{frame_ext}')
            frame_files.append(frame_path)
            plt.savefig(frame_path)
    
    if movie_dir:
        movie_path = os.path.join(movie_dir, movie_name)
        with imageio.get_writer(movie_path, mode='I') as writer:
            for frame in frame_files:
                image = imageio.imread(frame)
                writer.append_data(image)
                
    if movie_dir and remove_frames:
        for frame in frame_files:
            try:
                os.remove(frame)
            except:
                pass

# %% [markdown]
# ## Movie Parameters

# %%
data_dir = 'data/Wave1D'
data_filename = 'data.npz'
data_path = os.path.join(data_dir, data_filename)
# os.makedirs(data_dir, exist_ok=True)
test_x, test_y, preds_y = load_data(data_path)

movie_dir = 'Wave1D/movie/'
os.makedirs(movie_dir, exist_ok=True)

# %%
# %matplotlib inline
key = 0
movie_name = f'Wave1D_{key}.gif'
frame_basename = f'Wave1D_{key}_frame'
frame_ext = 'jpg'
plot_title = "Wave Equation"
font_size = 12
remove_frames = True

generate_movie_1D(key, test_x, test_y, preds_y, plot_title=plot_title, movie_dir=movie_dir, movie_name=movie_name, frame_basename=frame_basename, frame_ext=frame_ext, remove_frames=remove_frames, font_size=font_size)
# Out:
# /tmp/ipykernel_266365/1527175883.py:68: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(frame)

# %%
# %matplotlib inline
key = 1
movie_name = f'Wave1D_{key}.gif'
frame_basename = f'Wave1D_{key}_frame'
frame_ext = 'jpg'
plot_title = "Wave Equation"
font_size = 12
remove_frames = True

generate_movie_1D(key, test_x, test_y, preds_y, plot_title=plot_title, movie_dir=movie_dir, movie_name=movie_name, frame_basename=frame_basename, frame_ext=frame_ext, remove_frames=remove_frames, font_size=font_size)
# Out:
# /tmp/ipykernel_266365/1527175883.py:68: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(frame)

# %%
# %matplotlib inline
key = 2
movie_name = f'Wave1D_{key}.gif'
frame_basename = f'Wave1D_{key}_frame'
frame_ext = 'jpg'
plot_title = "Wave Equation"
font_size = 12
remove_frames = True

generate_movie_1D(key, test_x, test_y, preds_y, plot_title=plot_title, movie_dir=movie_dir, movie_name=movie_name, frame_basename=frame_basename, frame_ext=frame_ext, remove_frames=remove_frames, font_size=font_size)
# Out:
# /tmp/ipykernel_266365/1527175883.py:68: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(frame)

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
plt.ion()


fig.show()
fig.canvas.draw()
diff = pred - true
ax.plot(x, pred[0] - true[0], 'b-', label='Difference')
# ax.plot(x, pred[0], 'r--', label='PINO Prediction')
ylim = [diff.min(), diff.max()]
xlim = [0, 1]
plt.xlim(xlim)
plt.ylim(ylim)
plt.tight_layout()



for i in range(Nt):
    ax.clear()
#     ax.plot(x, true[i], 'b-', label='Exact')
#     ax.plot(x, pred[i], 'r--', label='PINO Prediction')
    ax.plot(x, diff[i], 'b-', label='Difference')
    plt.ylim(ylim)
    plt.xlim(xlim)
    plt.xlabel(f'$x$')
    plt.ylabel(f'$u$')
    plt.title(f'Wave Equation')
    plt.legend(loc='lower right')
    plt.tight_layout()
    fig.canvas.draw()
# Out:
# <div id='7c8de307-5473-4d3b-94c1-d4ccee4ef445'></div>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
