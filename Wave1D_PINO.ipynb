# %%
# Noise robustness experiment (branch plan):
# Add additive Gaussian noise to the training trajectories u only
# (leave the initial conditions a and the test set clean), sweep noise
# levels {0, 1%, 5%, 10%, 20%} of the signal std, retrain at each level,
# and plot relative L2 error and physics residual vs. noise level.
#
# Other ways we could deal with / study noise:
# - Where to inject: on a instead of u, on both, or only at test time.
# - Noise model: Laplace / heavy-tailed, multiplicative, spatially or
#   temporally correlated, spikes / missing values / quantization.
# - Mitigation: lower data_weight relative to ic_loss / f_loss, use
#   L1 or Huber data loss, denoise u (spectral low-pass) before training,
#   augment with multiple noise realizations per sample, or ensemble
#   models trained on independently noised copies.
# - Measure: not just rel. L2 + residual, but also variance across noise
#   seeds and the shape of the degradation curve (smooth slope vs. sharp
#   breakdown, like our resolution sweep).

# %% [markdown]
# # Import Libraries

# %%
import os
os.environ["OMP_NUM_THREADS"] = "2"
os.environ["MKL_NUM_THREADS"] = "2"
os.environ["OPENBLAS_NUM_THREADS"] = "2"
os.environ["NUMEXPR_NUM_THREADS"] = "2"

import torch
torch.set_num_threads(2)
torch.set_num_interop_threads(2)
torch.cuda.set_device(3)
print(f"Using GPU: {torch.cuda.current_device()} "
      f"({torch.cuda.get_device_name(3)})")
# Out:
# Using GPU: 3 (Quadro RTX 6000)

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib notebook
from argparse import ArgumentParser
import yaml
import os
import math
import torch
# from torch import vmap
from torch.func import vmap, grad
from models import FNN2d
from train_utils import Adam
# from train_utils.datasets import BurgersLoader
# from train_utils.train_2d import train_2d_burger
# from train_utils.eval_2d import eval_burgers

from solver.WaveEq import WaveEq1D
import traceback

import scipy.io
import torch.nn.functional as F
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import imageio


from tqdm import tqdm
from train_utils.utils import save_checkpoint, load_checkpoint, update_config, load_config
from train_utils.losses import LpLoss
from train_utils.datasets import DataLoader1D

from solver.my_random_fields import GRF_Mattern

from importlib import reload

try:
    import wandb
except ImportError:
    wandb = None
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Define Loss Functions

# %% [markdown]
# ## Spectral Derivatives

# %%
def FDM_Wave(u, D=1, c=1.0):
    batchsize = u.size(0)
    nt = u.size(1)
    nx = u.size(2)

    u = u.reshape(batchsize, nt, nx)
    dt = D / (nt-1)
    dx = D / (nx)

    u_h = torch.fft.fft(u, dim=2)
    # Wavenumbers in y-direction
    k_max = nx//2
    k_x = torch.cat((torch.arange(start=0, end=k_max, step=1, device=u.device),
                     torch.arange(start=-k_max, end=0, step=1, device=u.device)), 0).reshape(1,1,nx)
    ux_h = 2j *np.pi*k_x*u_h
    uxx_h = 2j *np.pi*k_x*ux_h
    ux = torch.fft.irfft(ux_h[:, :, :k_max+1], dim=2, n=nx)
    uxx = torch.fft.irfft(uxx_h[:, :, :k_max+1], dim=2, n=nx)
    ut = (u[:, 2:, :] - u[:, :-2, :]) / (2 * dt)
    utt = (u[:, 2:, :] - 2.0*u[:, 1:-1, :] + u[:, :-2, :]) / (dt**2)
    Du = utt - c**2 * uxx[:,1:-1,:]
    return Du


def PINO_loss_wave(u, u0, c=1.0):
    batchsize = u.size(0)
    nt = u.size(1)
    nx = u.size(2)

    u = u.reshape(batchsize, nt, nx)
    # lploss = LpLoss(size_average=True)

    index_t = torch.zeros(nx,).long()
    index_x = torch.tensor(range(nx)).long()
    boundary_u = u[:, index_t, index_x]
    loss_u = F.mse_loss(boundary_u, u0)

    Du = FDM_Wave(u, c=c)[:, :, :]
    f = torch.zeros(Du.shape, device=u.device)
    loss_f = F.mse_loss(Du, f)

    # loss_bc0 = F.mse_loss(u[:, :, 0], u[:, :, -1])
    # loss_bc1 = F.mse_loss((u[:, :, 1] - u[:, :, -1]) /
    #                       (2/(nx)), (u[:, :, 0] - u[:, :, -2])/(2/(nx)))
    return loss_u, loss_f

# %% [markdown]
# # Define Training Function

# %%
def train_wave(model,
               train_loader,
               optimizer, 
               scheduler,
               config,
               rank=3, 
               log=False,
               project='PINO-2d-default',
               group='default',
               tags=['default'],
               use_tqdm=True):
    if rank == 0 and wandb and log:
        run = wandb.init(project=project,
                         entity='shawngr2',
                         group=group,
                         config=config,
                         tags=tags, reinit=True,
                         settings=wandb.Settings(start_method="fork"))

    data_weight = config['train']['xy_loss']
    f_weight = config['train']['f_loss']
    ic_weight = config['train']['ic_loss']
    c = config['data']['c']
    ckpt_freq = config['train']['ckpt_freq']
    model.train()
    myloss = LpLoss(size_average=True)
    pbar = range(config['train']['epochs'])
    if use_tqdm:
        pbar = tqdm(pbar, dynamic_ncols=True, smoothing=0.1)

    for e in pbar:
        model.train()
        train_pino = 0.0
        data_l2 = 0.0
        train_ic = 0.0
        train_loss = 0.0

        for x, y in train_loader:
            x, y = x.to(rank), y.to(rank)
#             display(x.shape, y.shape)
            out = model(x).reshape(y.shape)
            data_loss = myloss(out, y)

            loss_ic, loss_f = PINO_loss_wave(out, x[:, 0, :, 0], c=c)
            total_loss = loss_ic * ic_weight + loss_f * f_weight + data_loss * data_weight

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            data_l2 += data_loss.item()
            train_pino += loss_f.item()
            train_loss += total_loss.item()
            train_ic += loss_ic.item()
        scheduler.step()
        data_l2 /= len(train_loader)
        train_pino /= len(train_loader)
        train_loss /= len(train_loader)
        if use_tqdm:
            pbar.set_description(
                (
                    f'Epoch {e}, train loss: {train_loss:.5f} '
                    f'train f error: {train_pino:.5f}; '
                    f'data l2 error: {data_l2:.5f}; '
                    f'train ic error: {train_ic:.5f}'
                )
            )
        if wandb and log:
            wandb.log(
                {
                    'Train f error': train_pino,
                    'Train L2 error': data_l2,
                    'Train ic error': loss_ic,
                    'Train loss': train_loss,
                }
            )

        if e % ckpt_freq == 0:
            save_checkpoint(config['train']['save_dir'],
                            config['train']['save_name'].replace('.pt', f'_{e}.pt'),
                            model, optimizer)
    save_checkpoint(config['train']['save_dir'],
                    config['train']['save_name'],
                    model, optimizer)
    print('Done!')

# %% [markdown]
# # Evaluation Function

# %%
def eval_wave(model,
              dataloader,
              config,
              device,
              use_tqdm=True):
    model.eval()
    myloss = LpLoss(size_average=True)
    c = config['data']['c']
    if use_tqdm:
        pbar = tqdm(dataloader, dynamic_ncols=True, smoothing=0.05)
    else:
        pbar = dataloader

    test_err = []
    f_err = []

    for x, y in pbar:
        x, y = x.to(device), y.to(device)
        out = model(x).reshape(y.shape)
        data_loss = myloss(out, y)

        loss_u, f_loss = PINO_loss_wave(out, x[:, 0, :, 0], c=c)
        test_err.append(data_loss.item())
        f_err.append(f_loss.item())

    mean_f_err = np.mean(f_err)
    std_f_err = np.std(f_err, ddof=1) / np.sqrt(len(f_err))

    mean_err = np.mean(test_err)
    std_err = np.std(test_err, ddof=1) / np.sqrt(len(test_err))

    print(f'==Averaged relative L2 error mean: {mean_err}, std error: {std_err}==\n'
          f'==Averaged equation error mean: {mean_f_err}, std error: {std_f_err}==')

# %% [markdown]
# # Load Config File

# %%
config_file = 'configs/custom/wave-0000.yaml'
config = load_config(config_file)
display(config)
# Out:
# {'data': {'name': 'Wave-0000',
#   'total_num': 1000,
#   'n_train': 900,
#   'n_test': 100,
#   'nx': 4096,
#   'nt': 100,
#   'sub': 32,
#   'sub_t': 1,
#   'c': 1.0},
#  'model': {'layers': [16, 24, 24, 32, 32],
#   'modes1': [15, 12, 9, 9],
#   'modes2': [15, 12, 9, 9],
#   'fc_dim': 128,
#   'activation': 'gelu'},
#  'train': {'batchsize': 20,
#   'epochs': 500,
#   'milestones': [150, 300, 450],
#   'base_lr': 0.001,
#   'scheduler_gamma': 0.5,
#   'ic_loss': 5.0,
#   'f_loss': 1.0,
#   'xy_loss': 10.0,
#   'save_dir': 'Wave',
#   'save_name': 'Wave-eqn.pt',
#   'ckpt': 'checkpoints/Wave/Wave-eqn.pt',
#   'ckpt_freq': 100},
#  'log': {'project': 'PINO-Wave', 'group': 'Wave-0000'},
#  'test': {'batchsize': 1, 'ckpt': 'checkpoints/Wave/Wave-eqn.pt'}}

# %% [markdown]
# # Parameters

# %%
Nsamples = config['data']['total_num']
N = config['data']['nx']
Nt0 = config['data']['nt']
c = config['data']['c']
sub_x = config['data']['sub']
sub_t = config['data']['sub_t']
Nx = N // sub_x
Nt = Nt0 // sub_t + 1
dim = 1
l = 0.1
L = 1.0
sigma = 0.2 #2.0
Nu = None # 2.0
dt = 1.0e-4
tend = 1.0
save_int = int(tend/dt/Nt)

device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda', index=3)

# %% [markdown]
# # Generate Random Fields

# %%
grf = GRF_Mattern(dim, N, length=L, nu=Nu, l=l, sigma=sigma, boundary="periodic", device=device)
U0 = grf.sample(Nsamples)

# %%
wave_eq = WaveEq1D(Nx=N, c=c, dt=dt, device=device)
U = vmap(wave_eq.wave_driver, in_dims=(0, None))(U0, save_int)

# %%
a = U0.cpu().float()
u = U.cpu().float()

display(u.shape,a.shape)
# Out:
# torch.Size([1000, 102, 4096])
# torch.Size([1000, 4096])

# %%
from train_utils.datasets import DataLoader1D

# %%
dataset = DataLoader1D(a, u, config['data']['nx'], config['data']['nt'], config['data']['sub'], config['data']['sub_t'])
train_loader = dataset.make_loader(config['data']['n_train'], config['train']['batchsize'], start=0, train=True)
test_loader = dataset.make_loader(config['data']['n_test'], config['test']['batchsize'], start=config['data']['n_train'], train=False)

# %%
log = False
model = FNN2d(modes1=config['model']['modes1'],
                  modes2=config['model']['modes2'],
                  fc_dim=config['model']['fc_dim'],
                  layers=config['model']['layers'],
                  activation=config['model']['activation']).to(device)

optimizer = Adam(model.parameters(), betas=(0.9, 0.999),lr=config['train']['base_lr'])
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer,
                                                 milestones=config['train']['milestones'],
                                                 gamma=config['train']['scheduler_gamma'])

# %% [markdown]
# # Load from checkpoint

# %%
load_checkpoint(model, ckpt_path=config['train']['ckpt'], optimizer=None)
# Out:
# Weights loaded from checkpoints/Wave/Wave-eqn.pt

# %% [markdown]
# # Train the Model

# %%
train_wave(model,
           train_loader,
           optimizer,
           scheduler,
           config,
           rank=3,
           log=log,
           project=config['log']['project'],
           group=config['log']['group'])
# Out:
# Epoch 0, train loss: 10.37896 train f error: 0.27874; data l2 error: 1.00630; train ic error: 0.33503:   0%|          | 1/500 [00:02<17:54,  2.15s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_0.pt
# Epoch 100, train loss: 0.18123 train f error: 0.05471; data l2 error: 0.01265; train ic error: 0.00005:  20%|██        | 101/500 [02:32<09:53,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_100.pt
# Epoch 200, train loss: 0.11065 train f error: 0.06468; data l2 error: 0.00460; train ic error: 0.00001:  40%|████      | 201/500 [05:01<07:25,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_200.pt
# Epoch 300, train loss: 0.10400 train f error: 0.06489; data l2 error: 0.00391; train ic error: 0.00001:  60%|██████    | 301/500 [07:32<04:55,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_300.pt
# Epoch 400, train loss: 0.10016 train f error: 0.06738; data l2 error: 0.00328; train ic error: 0.00001:  80%|████████  | 401/500 [10:01<02:29,  1.51s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn_400.pt
# Epoch 499, train loss: 0.08438 train f error: 0.07227; data l2 error: 0.00121; train ic error: 0.00000: 100%|██████████| 500/500 [12:30<00:00,  1.50s/it]
# Checkpoint is saved at checkpoints/Wave/Wave-eqn.pt
# Done!

# %% [markdown]
# # Evaluate on Test Data

# %%
eval_wave(model, test_loader, config, device)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 174.99it/s]
# ==Averaged relative L2 error mean: 0.0011367931886343285, std error: 2.7460000279596653e-05==
# ==Averaged equation error mean: 0.07551815146580339, std error: 0.0036252262024251947==

# %%
eval_wave(model, test_loader, config, device)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 289.14it/s]
# ==Averaged relative L2 error mean: 0.0011367931886343285, std error: 2.7460000279596653e-05==
# ==Averaged equation error mean: 0.07551815146580339, std error: 0.0036252262024251947==

# %%
# =============================================================================
# PINO Multi-Resolution Experiment
# -----------------------------------------------------------------------------
# Goal: replicate the spirit of the original resolution sweep (sub_x_list sweep
#       producing Nx = 32 → 4096) but fix it to match the PINO paper's actual
#       experimental design.
#
# What the original code did wrong:
#   1. Trained with data AND PDE loss at the SAME resolution. The paper's key
#      claim is that you train with data at low-res but PDE loss at HIGH-res.
#      That's what gives you robust super-resolution at eval time.
#   2. The physics residual (MSE of FDM_Wave) scales as O(1/Nx^2) because dt and
#      the absolute magnitudes of utt shrink as the grid gets finer — so even a
#      "perfect" model would look better at higher Nx. We fix this by normalizing.
#
# What this cell does:
#   Step 1 — PINO training: data at 1× resolution, PDE loss upsampled to 16×.
#            This is the paper's recipe extended to 16× so the model "knows"
#            about all the frequencies we're about to test.
#   Step 2 — Resolution sweep: evaluate the trained model at 1×, 2×, 4×, 8×,
#            16× (matching the original code's ambition) and report both:
#              - relative L2 error  (same as the original code)
#              - NORMALIZED physics residual: divide raw MSE by (dt^2 * Nx * Nt)
#                so the number is dimensionless and resolution-comparable.
#   Step 3 — Plot both metrics side by side.
#
# Assumptions (matching your existing notebook):
#   - `a`, `u`, `N`, `Nt0`, `c`, `sub_t`, `device` are already defined.
#   - `config` is already loaded from the yaml.
#   - `FNN2d`, `Adam`, `DataLoader1D`, `LpLoss`, `save_checkpoint` are imported.
#   - `FDM_Wave` and `PINO_loss_wave` are defined as in your notebook.
# =============================================================================

import copy
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from train_utils.losses import LpLoss
from train_utils.datasets import DataLoader1D
from train_utils.utils import save_checkpoint


# ── 0. Configuration ──────────────────────────────────────────────────────────

# Data (low) resolution — use whatever sub is in your config
sub_x_data = config['data']['sub']        # e.g. 32  → Nx_data = N // 32
sub_t_data = config['data']['sub_t']

# PDE loss resolution — highest resolution we want to test at eval time
# The paper uses 4× the data res; we go to 16× to match the original sweep.
# sub_x_pde must divide N and satisfy sub_x_pde <= sub_x_data.
pde_multiplier = 16                        # train PDE loss at 16× data res
sub_x_pde = max(1, sub_x_data // pde_multiplier)

Nx_data = N // sub_x_data
Nx_pde  = N // sub_x_pde

print(f"Data resolution : Nx = {Nx_data}  (sub_x = {sub_x_data})")
print(f"PDE  resolution : Nx = {Nx_pde}   (sub_x = {sub_x_pde})  [{pde_multiplier}× data res]")
print(f"Temporal points : Nt = {Nt0 // sub_t_data + 1}")


# ── 1. Modified training loop with high-res PDE loss ─────────────────────────
#
# The existing train_wave function evaluates PDE loss on the same grid as the
# data.  We need a second loader at the PDE resolution to supply initial
# conditions so the model can be queried at that finer grid and the wave
# residual computed there.
#
# Concretely, each training iteration:
#   a) Forward pass on low-res batch  → data loss + low-res PDE loss
#   b) Forward pass on high-res batch (same IC samples, finer grid) → high-res PDE loss
#   Total loss = data_loss * w_data + ic_loss * w_ic + pde_loss_highres * w_f

def train_wave_multires(model,
                        train_loader_data,   # low-res data batches (x, y)
                        train_loader_pde,    # high-res batches (x_hi, y_hi) — y_hi not used
                        optimizer,
                        scheduler,
                        config,
                        epochs=None,
                        device='cpu'):
    """
    Train PINO with data loss at data resolution and PDE loss at pde resolution.
    train_loader_pde can be longer or shorter than train_loader_data; we cycle it.
    """
    data_weight = config['train']['xy_loss']
    f_weight    = config['train']['f_loss']
    ic_weight   = config['train']['ic_loss']
    c_val       = config['data']['c']
    n_epochs    = epochs if epochs is not None else config['train']['epochs']
    myloss      = LpLoss(size_average=True)

    # Make the high-res loader an infinite iterator so lengths don't have to match
    def cycle(loader):
        while True:
            for batch in loader:
                yield batch

    pde_iter = cycle(train_loader_pde)

    pbar = tqdm(range(n_epochs), dynamic_ncols=True, smoothing=0.1)
    for e in pbar:
        model.train()
        epoch_data_l2 = 0.0
        epoch_pde     = 0.0
        epoch_ic      = 0.0
        epoch_total   = 0.0

        for x_lo, y_lo in train_loader_data:
            x_lo, y_lo = x_lo.to(device), y_lo.to(device)

            # ── (a) data loss at training resolution ──────────────────────
            out_lo    = model(x_lo).reshape(y_lo.shape)
            data_loss = myloss(out_lo, y_lo)

            # ── (b) PDE loss at high resolution ───────────────────────────
            # x_hi carries the same initial conditions on a finer grid;
            # we only need the IC (first time row) from it.
            x_hi, _ = next(pde_iter)
            x_hi    = x_hi.to(device)
            out_hi  = model(x_hi).reshape(x_hi.shape[0],
                                          x_hi.shape[1],   # Nt
                                          x_hi.shape[2])   # Nx_pde
            # IC at high res: x_hi[:, 0, :, 0]  (same shape convention as low-res)
            loss_ic_hi, loss_f_hi = PINO_loss_wave(out_hi, x_hi[:, 0, :, 0], c=c_val)

            total_loss = (data_loss   * data_weight
                        + loss_ic_hi * ic_weight
                        + loss_f_hi  * f_weight)

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            epoch_data_l2 += data_loss.item()
            epoch_pde     += loss_f_hi.item()
            epoch_ic      += loss_ic_hi.item()
            epoch_total   += total_loss.item()

        n = len(train_loader_data)
        scheduler.step()
        pbar.set_description(
            f'Ep {e}  loss={epoch_total/n:.4f}  '
            f'data={epoch_data_l2/n:.4f}  '
            f'pde(hi)={epoch_pde/n:.5f}  '
            f'ic={epoch_ic/n:.5f}'
        )

    print('Training done.')


# ── 2. Build data loaders ─────────────────────────────────────────────────────

n_train = config['data']['n_train']
n_test  = config['data']['n_test']
bs      = config['train']['batchsize']
bs_test = config['test']['batchsize']

# Smaller batch size for the high-res PDE loader to avoid OOM at Nx_pde=2048.
# At bs=20 the high-res activation tensor (~2 GB each) overflows the 24 GB GPU
# once you include the backward graph + Adam state + low-res forward.
bs_pde  = 20                                          # ADDED (was: bs = 20 used for both loaders)

# Low-res loader (data + low-res PDE during old training, now only data loss)
ds_data        = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_data, sub_t=sub_t_data)
train_loader   = ds_data.make_loader(n_train, bs,      start=0,       train=True)
test_loader    = ds_data.make_loader(n_test,  bs_test, start=n_train, train=False)

# High-res loader for PDE loss (same samples, finer grid, ground truth ignored)
ds_pde         = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_pde, sub_t=sub_t_data)
train_loader_pde = ds_pde.make_loader(n_train, bs_pde, start=0, train=True)   # CHANGED bs -> bs_pde


# ── 3. Initialise a fresh model and train ────────────────────────────────────

# Short-run training config for this resolution-invariance experiment.
# At ~50-60 s/epoch on this GPU with bs_pde=8, 50 epochs ≈ 50 min. The compressed
# milestones below mirror what we did for the noise sweep so the LR scheduler
# actually fires inside such a short run.
multires_epochs     = 50
multires_milestones = [20, 35]

model_pino = FNN2d(
    modes1=config['model']['modes1'],
    modes2=config['model']['modes2'],
    fc_dim=config['model']['fc_dim'],
    layers=config['model']['layers'],
    activation=config['model']['activation'],
).to(device)

optimizer_pino = Adam(model_pino.parameters(), betas=(0.9, 0.999),
                      lr=config['train']['base_lr'])
scheduler_pino = torch.optim.lr_scheduler.MultiStepLR(
    optimizer_pino,
    milestones=config['train']['milestones'],                  # CHANGED (was: config['train']['milestones'])
    gamma=config['train']['scheduler_gamma'],
)

print(f"\n{'='*60}")
print(f"Training PINO (data @ 1×, PDE loss @ 16×) for {multires_epochs} epochs ...")
print(f"{'='*60}\n")

train_wave_multires(
    model_pino,
    train_loader,
    train_loader_pde,
    optimizer_pino,
    scheduler_pino,
    config,
    epochs=config['train']['epochs'],                          # ADDED (was: not passed -> defaulted to config['train']['epochs']=500)
    device=device,
)

# Optionally save
save_checkpoint(config['train']['save_dir'],
                config['train']['save_name'].replace('.pt', '_multires16x.pt'),
                model_pino, optimizer_pino)


# ── 4. Resolution sweep evaluation ───────────────────────────────────────────
#
# We sweep the SAME multipliers as the original code (up to 16×).
# Physics residual fix: divide raw MSE by (1/Nx / 1/Nt)^scale so it's
# dimensionless.  The cleanest normalization is:
#
#   normalized_residual = sqrt(MSE(Du)) / (||u||_rms / T)
#
# i.e. the RMS residual divided by the RMS solution scaled by the time window.
# This makes the number ≈ 1 for a random model and → 0 for a perfect one,
# regardless of grid size.

def compute_normalized_physics_residual(out, c_val):
    """
    Returns a dimensionless physics residual:
        RMS( u_tt - c²·u_xx ) / RMS( u_tt )
    We use u_tt as the normalizer because it has the same physical dimensions
    as the residual, and it captures the scale of the second-order dynamics
    without referencing ground truth.
    """
    Du = FDM_Wave(out, D=1.0, c=c_val)          # shape (B, Nt-2, Nx)
    nt = out.size(1)
    dt = 1.0 / (nt - 1)
    utt = (out[:, 2:, :] - 2.0 * out[:, 1:-1, :] + out[:, :-2, :]) / (dt ** 2)

    rms_res = Du.pow(2).mean().sqrt()
    rms_utt = utt.pow(2).mean().sqrt().clamp(min=1e-8)
    return (rms_res / rms_utt).item()


# Multipliers to test: [1, 2, 4, 8, 16]  → sub_x = [sub_x_data, /2, /4, /8, /16]
eval_multipliers = [1, 2, 4, 8, 16]
results = []   # (Nx, rel_L2, norm_phys)

myloss = LpLoss(size_average=True)

for mult in eval_multipliers:
    sub_x_eval = max(1, sub_x_data // mult)
    if N // sub_x_eval < 2 * max(config['model']['modes2']):
        # FNO needs Nx >= 2 * modes to run — skip if too small
        print(f"Skipping {mult}× (Nx={N//sub_x_eval} < 2×modes={2*config['model']['modes2']})")
        continue

    Nx_eval = N // sub_x_eval
    print(f"\n--- Evaluating at {mult}× (Nx={Nx_eval}, sub_x={sub_x_eval}) ---",
          end=" ", flush=True)

    ds_eval   = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_eval, sub_t=sub_t_data)
    loader_ev = ds_eval.make_loader(n_test, bs_test, start=n_train, train=False)

    l2_list, phys_list = [], []
    model_pino.eval()
    with torch.no_grad():
        for x_ev, y_ev in loader_ev:
            x_ev, y_ev = x_ev.to(device), y_ev.to(device)
            out_ev = model_pino(x_ev).reshape(y_ev.shape)

            l2_list.append(myloss(out_ev, y_ev).item())
            phys_list.append(compute_normalized_physics_residual(out_ev, c))

    mean_l2   = float(np.mean(l2_list))
    mean_phys = float(np.mean(phys_list))
    print(f"rel L2 = {mean_l2:.4f},  norm phys = {mean_phys:.4e}")
    results.append((Nx_eval, mult, mean_l2, mean_phys))


# ── 5. Plot ───────────────────────────────────────────────────────────────────

results = np.array(results)   # columns: Nx, mult, rel_L2, norm_phys
Nx_vals   = results[:, 0]
mult_vals = results[:, 1]
l2_vals   = results[:, 2]
phys_vals = results[:, 3]

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# -- Panel 1: Relative L2 error
ax = axes[0]
ax.plot(mult_vals, l2_vals * 100, 'o-', color='tab:blue', lw=2, ms=8)
ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
for m, l2 in zip(mult_vals, l2_vals):
    ax.annotate(f'{l2*100:.2f}%', (m, l2*100),
                textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
ax.set_xticks(mult_vals)
ax.set_xticklabels([f'{int(m)}×\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
ax.set_xlabel('Eval resolution (× training data resolution)')
ax.set_ylabel('Relative $L^2$ error (%)')
ax.set_title('Prediction error vs resolution\n(should stay flat for PINO)')
ax.legend()
ax.grid(True, alpha=0.3)

# -- Panel 2: Normalized physics residual
ax = axes[1]
ax.plot(mult_vals, phys_vals, 's-', color='tab:orange', lw=2, ms=8)
ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
for m, ph in zip(mult_vals, phys_vals):
    ax.annotate(f'{ph:.3f}', (m, ph),
                textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
ax.set_xticks(mult_vals)
ax.set_xticklabels([f'{int(m)}×\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
ax.set_xlabel('Eval resolution (× training data resolution)')
ax.set_ylabel('Norm. physics residual\n$\\sqrt{\\mathrm{MSE}(u_{tt} - c^2 u_{xx})} / \\sqrt{\\mathrm{MSE}(u_{tt})}$')
ax.set_title('Physics residual vs resolution\n(normalized: dimensionless across grids)')
ax.legend()
ax.grid(True, alpha=0.3)

plt.suptitle(
    f'PINO Wave 1D — Resolution Invariance\n'
    f'Data @ Nx={Nx_data} (1×),  PDE loss @ Nx={Nx_pde} ({pde_multiplier}×)',
    y=1.03
)
plt.tight_layout()
plt.show()

# ── 6. Summary table ──────────────────────────────────────────────────────────

print(f"\n{'='*58}")
print(f"  {'Mult':>4}  {'Nx':>6}  {'Rel L2 (%)':>12}  {'Norm Phys Res':>15}")
print(f"{'='*58}")
for nx, mult, l2, phys in results:
    tag = " ← train" if int(mult) == 1 else (
          f" ← PDE train" if int(nx) == Nx_pde else "")
    print(f"  {int(mult):>4}×  {int(nx):>6}  {l2*100:>12.3f}%  {phys:>15.4e}{tag}")
print(f"{'='*58}")
print(
    "\nInterpretation:"
    "\n  L2 error   — should be roughly flat (paper's claim). If it rises"
    "\n               steeply, the model isn't generalizing to unseen frequencies."
    "\n  Norm phys  — RMS residual / RMS(u_tt). A value near 0 means the model"
    "\n               satisfies the wave equation at that resolution. Because we"
    "\n               divide by u_tt, this is comparable across all Nx values."
    "\n               Training PDE loss at 16× should keep this small up to 16×."
)
# Out:
# Data resolution : Nx = 128  (sub_x = 32)
# PDE  resolution : Nx = 2048   (sub_x = 2)  [16× data res]
# Temporal points : Nt = 101
#
# ============================================================
# Training PINO (data @ 1×, PDE loss @ 16×) for 50 epochs ...
# ============================================================
# Ep 0  loss=17659.3616  data=1.0051  pde(hi)=17649.27354  ic=0.00743:   0%|          | 1/500 [00:23<3:12:57, 23.20s/it]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

train_nx = config['data']['nx'] // config['data']['sub']

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
ax.plot(results[:, 0], results[:, 1], 'o-', color='tab:blue')
ax.axvline(train_nx, color='gray', ls='--', label=f'Train resolution (Nx={train_nx})')
ax.set_xscale('log', base=2)
ax.set_xlabel('Spatial resolution Nx (eval)')
ax.set_ylabel('Relative L2 error')
ax.set_title('Prediction error vs resolution')
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(results[:, 0], results[:, 2], 's-', color='tab:orange')
ax.axvline(train_nx, color='gray', ls='--', label=f'Train resolution (Nx={train_nx})')
ax.set_xscale('log', base=2)
ax.set_yscale('log')
ax.set_xlabel('Spatial resolution Nx (eval)')
ax.set_ylabel('PDE equation residual')
ax.set_title('Physics residual vs resolution')
ax.legend()
ax.grid(True, alpha=0.3, which='both')

plt.suptitle('Resolution invariance — Wave 1D PINO', y=1.02)
plt.tight_layout()
plt.show()

# %%
# # Eval + plot only — uses model_pino already trained in the previous cell.
# import numpy as np
# import matplotlib.pyplot as plt
# from train_utils.losses import LpLoss
# from train_utils.datasets import DataLoader1D

# eval_multipliers = [1, 2, 4, 8, 16]
# max_mode_x = max(config['model']['modes2'])
# myloss = LpLoss(size_average=True)

# results = []
# for mult in eval_multipliers:
#     sub_x_eval = max(1, sub_x_data // mult)
#     if N // sub_x_eval < 2 * max_mode_x:
#         print(f"Skipping {mult}x (Nx={N//sub_x_eval} < 2*max_mode={2*max_mode_x})")
#         continue

#     Nx_eval = N // sub_x_eval
#     print(f"--- Evaluating at {mult}x (Nx={Nx_eval}) ---", end=" ", flush=True)

#     ds_eval   = DataLoader1D(a, u, nx=N, nt=Nt0, sub=sub_x_eval, sub_t=sub_t_data)
#     loader_ev = ds_eval.make_loader(n_test, bs_test, start=n_train, train=False)

#     l2_list, phys_list = [], []
#     model_pino.eval()
#     with torch.no_grad():
#         for x_ev, y_ev in loader_ev:
#             x_ev, y_ev = x_ev.to(device), y_ev.to(device)
#             out_ev = model_pino(x_ev).reshape(y_ev.shape)
#             l2_list.append(myloss(out_ev, y_ev).item())
#             phys_list.append(compute_normalized_physics_residual(out_ev, c))

#     mean_l2   = float(np.mean(l2_list))
#     mean_phys = float(np.mean(phys_list))
#     print(f"rel L2 = {mean_l2:.4f},  norm phys = {mean_phys:.4e}")
#     results.append((Nx_eval, mult, mean_l2, mean_phys))

# results = np.array(results)
# Nx_vals, mult_vals = results[:, 0], results[:, 1]
# l2_vals, phys_vals = results[:, 2], results[:, 3]

# fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# ax = axes[0]
# ax.plot(mult_vals, l2_vals * 100, 'o-', color='tab:blue', lw=2, ms=8)
# ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
# for m, l2 in zip(mult_vals, l2_vals):
#     ax.annotate(f'{l2*100:.2f}%', (m, l2*100),
#                 textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
# ax.set_xticks(mult_vals)
# ax.set_xticklabels([f'{int(m)}x\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
# ax.set_xlabel('Eval resolution (x training data resolution)')
# ax.set_ylabel('Relative L2 error (%)')
# ax.set_title('Prediction error vs resolution')
# ax.legend()
# ax.grid(True, alpha=0.3)

# ax = axes[1]
# ax.plot(mult_vals, phys_vals, 's-', color='tab:orange', lw=2, ms=8)
# ax.axvline(1, color='gray', ls='--', lw=1.5, label=f'Train res (Nx={Nx_data})')
# for m, ph in zip(mult_vals, phys_vals):
#     ax.annotate(f'{ph:.3f}', (m, ph),
#                 textcoords='offset points', xytext=(0, 8), ha='center', fontsize=9)
# ax.set_xticks(mult_vals)
# ax.set_xticklabels([f'{int(m)}x\n(Nx={int(nx)})' for m, nx in zip(mult_vals, Nx_vals)])
# ax.set_xlabel('Eval resolution (x training data resolution)')
# ax.set_ylabel('Norm. physics residual')
# ax.set_title('Physics residual vs resolution')
# ax.legend()
# ax.grid(True, alpha=0.3)

# plt.suptitle(
#     f'PINO Wave 1D — Resolution Invariance\n'
#     f'Data @ Nx={Nx_data} (1x), PDE loss @ Nx={Nx_pde} ({pde_multiplier}x)',
#     y=1.03
# )
# plt.tight_layout()
# plt.show()

# print(f"\n{'='*58}")
# print(f"  {'Mult':>4}  {'Nx':>6}  {'Rel L2 (%)':>12}  {'Norm Phys Res':>15}")
# print(f"{'='*58}")
# for nx, mult, l2, phys in results:
#     tag = " <- train" if int(mult) == 1 else (
#           f" <- PDE train" if int(nx) == Nx_pde else "")
#     print(f"  {int(mult):>4}x  {int(nx):>6}  {l2*100:>12.3f}%  {phys:>15.4e}{tag}")
# print(f"{'='*58}")

# %%
Nx = config['data']['nx'] // config['data']['sub']
Nt = config['data']['nt'] // config['data']['sub_t'] + 1
Ntest = config['data']['n_test']
model.eval()
test_x = np.zeros((Ntest,Nt,Nx,3))
preds_y = np.zeros((Ntest,Nt,Nx))
test_y = np.zeros((Ntest,Nt,Nx))
with torch.no_grad():
    for i, data in enumerate(test_loader):
        data_x, data_y = data
        data_x, data_y = data_x.to(device), data_y.to(device)
        pred_y = model(data_x).reshape(data_y.shape)
        test_x[i] = data_x.cpu().numpy()
        test_y[i] = data_y.cpu().numpy()
        preds_y[i] = pred_y.cpu().numpy()
#     data_loss = myloss(out, y)

# %%
key = 1
pred = preds_y[key]
true = test_y[key]


a = test_x[key]
Nt, Nx, _ = a.shape
u0 = a[0,:,0]
T = a[:,:,2]
X = a[:,:,1]
x = X[0]

# %%
plt.rcParams.update({'font.size': 11})

# %%
fig = plt.figure(figsize=(24,5))
plt.subplot(1,4,1)

plt.plot(x, u0)
plt.xlabel('$x$')
plt.ylabel('$u$')
plt.title('Intial Condition $u(x)$')
plt.xlim([0,1])
plt.tight_layout()

plt.subplot(1,4,2)
# plt.pcolor(XX,TT, S_test, cmap='jet')
plt.pcolormesh(X, T, true, cmap='jet', shading='gouraud')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title(f'Exact $u(x,t)$')
plt.tight_layout()
plt.axis('square')

plt.subplot(1,4,3)
# plt.pcolor(XX,TT, S_pred, cmap='jet')
plt.pcolormesh(X, T, pred, cmap='jet', shading='gouraud')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title(f'Predict $u(x,t)$')
plt.axis('square')

plt.tight_layout()

plt.subplot(1,4,4)
# plt.pcolor(XX,TT, S_pred - S_test, cmap='jet')
plt.pcolormesh(X, T, pred - true, cmap='jet', shading='gouraud')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title('Absolute error')
plt.tight_layout()
plt.axis('square')

plt.show()

# %%
plt.show()

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
ax.plot(x, true[0], 'b-', label='Exact')
ax.plot(x, pred[0], 'r--', label='PINO Prediction')
ylim = plt.ylim()
xlim = [0, 1]
plt.tight_layout()



for i in range(Nt):
    ax.clear()
    ax.plot(x, true[i], 'b-', label='Exact')
    ax.plot(x, pred[i], 'r--', label='PINO Prediction')
    plt.ylim(ylim)
    plt.xlim(xlim)
    plt.xlabel(f'$x$')
    plt.ylabel(f'$u$')
    plt.title(f'Wave Equation')
    plt.legend(loc='lower right')
    plt.tight_layout()
    fig.canvas.draw()

# %% [markdown]
# # Save and Load Data

# %%
def save_data(data_path, test_x, test_y, preds_y):
    data_dir, data_filename = os.path.split(data_path)
    os.makedirs(data_dir, exist_ok=True)
    np.savez(data_path, test_x=test_x, test_y=test_y, preds_y=preds_y)

def load_data(data_path):
    data = np.load(data_path)
    test_x = data['test_x']
    test_y = data['test_y']
    preds_y = data['preds_y']
    return test_x, test_y, preds_y

# %%
data_dir = 'data/Wave1D'
data_filename = 'data.npz'
data_path = os.path.join(data_dir, data_filename)
# os.makedirs(data_dir, exist_ok=True)

# %%
save_data(data_path, test_x, test_y, preds_y)

# %%
test_x, test_y, preds_y = load_data(data_path)

# %%
def plot_predictions(key, test_x, test_y, preds_y, print_index=False, save_path=None, font_size=None):
    if font_size is not None:
        plt.rcParams.update({'font.size': font_size})
    pred = preds_y[key]
    true = test_y[key]


    a = test_x[key]
    Nt, Nx, _ = a.shape
    u0 = a[0,:,0]
    T = a[:,:,2]
    X = a[:,:,1]
    x = X[0]

    # Plot
    fig = plt.figure(figsize=(23,5))
    plt.subplot(1,4,1)

    plt.plot(x, u0)
    plt.xlabel('$x$')
    plt.ylabel('$u$')
    plt.title('Intial Condition $u(x)$')
    plt.xlim([0,1])
    plt.tight_layout()

    plt.subplot(1,4,2)
    # plt.pcolor(XX,TT, S_test, cmap='jet')
    plt.pcolormesh(X, T, true, cmap='jet', shading='gouraud')
    plt.colorbar()
    plt.xlabel('$x$')
    plt.ylabel('$t$')
    plt.title(f'Exact $u(x,t)$')
    plt.tight_layout()
    plt.axis('square')

    plt.subplot(1,4,3)
    # plt.pcolor(XX,TT, S_pred, cmap='jet')
    plt.pcolormesh(X, T, pred, cmap='jet', shading='gouraud')
    plt.colorbar()
    plt.xlabel('$x$')
    plt.ylabel('$t$')
    plt.title(f'Predict $u(x,t)$')
    plt.axis('square')

    plt.tight_layout()

    plt.subplot(1,4,4)
    # plt.pcolor(XX,TT, S_pred - S_test, cmap='jet')
    plt.pcolormesh(X, T, pred - true, cmap='jet', shading='gouraud')
    plt.colorbar()
    plt.xlabel('$x$')
    plt.ylabel('$t$')
    plt.title('Absolute Error')
    plt.tight_layout()
    plt.axis('square')

    if save_path is not None:
        plt.savefig(f'{save_path}.png', bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Movies

# %%
def generate_movie_1D(key, test_x, test_y, preds_y, plot_title='', movie_dir='', movie_name='movie.gif', frame_basename='movie', frame_ext='jpg', remove_frames=True, font_size=None):
    frame_files = []
    os.makedirs(movie_dir, exist_ok=True)

    if font_size is not None:
        plt.rcParams.update({'font.size': font_size})
    
    pred = preds_y[key]
    true = test_y[key]

    
    a = test_x[key]
    Nt, Nx, _ = a.shape
    u0 = a[0,:,0]
    T = a[:,:,2]
    X = a[:,:,1]
    x = X[0]
    t = T[:,0]

    fig = plt.figure(figsize=(6,5))
    ax = fig.add_subplot(111)
    plt.ion()

    fig.show()
    fig.canvas.draw()
    a = test_x[key]
    Nt, Nx, _ = a.shape
    u0 = a[0,:,0]
    T = a[:,:,2]
    X = a[:,:,1]
    x = X[0]
    ax.plot(x, true[0], 'b-', label='Exact')
    ax.plot(x, pred[0], 'r--', label='PINO Prediction')
    ylim = plt.ylim()
    xlim = [0, 1]
#     plt.xlim(xlim)
#     plt.xlabel(f'$x$')
#     plt.ylabel(f'$u$')
#     plt.title(f'{plot_title} $t={t[0]:.2f}$')
#     plt.legend(loc='lower right')
    plt.tight_layout()
    
    
    
    for i in range(Nt):
        ax.clear()
        ax.plot(x, true[i], 'b-', label='Exact')
        ax.plot(x, pred[i], 'r--', label='PINO Prediction')
        
        plt.xlabel(f'$x$')
        plt.ylabel(f'$u$')
        plt.title(f'{plot_title} $t={t[i]:.2f}$')
        plt.legend(loc='lower right')
        plt.ylim(ylim)
        plt.xlim(xlim)
        plt.tight_layout()
        fig.canvas.draw()
#         plt.show()
        if movie_dir:
            frame_path = os.path.join(movie_dir,f'{frame_basename}-{i:03}.{frame_ext}')
            frame_files.append(frame_path)
            plt.savefig(frame_path)
    
    if movie_dir:
        movie_path = os.path.join(movie_dir, movie_name)
        with imageio.get_writer(movie_path, mode='I') as writer:
            for frame in frame_files:
                image = imageio.imread(frame)
                writer.append_data(image)
                
    if movie_dir and remove_frames:
        for frame in frame_files:
            try:
                os.remove(frame)
            except:
                pass

# %% [markdown]
# ## Movie Parameters

# %%
data_dir = 'data/Wave1D'
data_filename = 'data.npz'
data_path = os.path.join(data_dir, data_filename)
# os.makedirs(data_dir, exist_ok=True)
test_x, test_y, preds_y = load_data(data_path)

movie_dir = 'Wave1D/movie/'
os.makedirs(movie_dir, exist_ok=True)

# %%
# %matplotlib inline
key = 0
movie_name = f'Wave1D_{key}.gif'
frame_basename = f'Wave1D_{key}_frame'
frame_ext = 'jpg'
plot_title = "Wave Equation"
font_size = 12
remove_frames = True

generate_movie_1D(key, test_x, test_y, preds_y, plot_title=plot_title, movie_dir=movie_dir, movie_name=movie_name, frame_basename=frame_basename, frame_ext=frame_ext, remove_frames=remove_frames, font_size=font_size)

# %%
# %matplotlib inline
key = 1
movie_name = f'Wave1D_{key}.gif'
frame_basename = f'Wave1D_{key}_frame'
frame_ext = 'jpg'
plot_title = "Wave Equation"
font_size = 12
remove_frames = True

generate_movie_1D(key, test_x, test_y, preds_y, plot_title=plot_title, movie_dir=movie_dir, movie_name=movie_name, frame_basename=frame_basename, frame_ext=frame_ext, remove_frames=remove_frames, font_size=font_size)

# %%
# %matplotlib inline
key = 2
movie_name = f'Wave1D_{key}.gif'
frame_basename = f'Wave1D_{key}_frame'
frame_ext = 'jpg'
plot_title = "Wave Equation"
font_size = 12
remove_frames = True

generate_movie_1D(key, test_x, test_y, preds_y, plot_title=plot_title, movie_dir=movie_dir, movie_name=movie_name, frame_basename=frame_basename, frame_ext=frame_ext, remove_frames=remove_frames, font_size=font_size)

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
plt.ion()


fig.show()
fig.canvas.draw()
diff = pred - true
ax.plot(x, pred[0] - true[0], 'b-', label='Difference')
# ax.plot(x, pred[0], 'r--', label='PINO Prediction')
ylim = [diff.min(), diff.max()]
xlim = [0, 1]
plt.xlim(xlim)
plt.ylim(ylim)
plt.tight_layout()



for i in range(Nt):
    ax.clear()
#     ax.plot(x, true[i], 'b-', label='Exact')
#     ax.plot(x, pred[i], 'r--', label='PINO Prediction')
    ax.plot(x, diff[i], 'b-', label='Difference')
    plt.ylim(ylim)
    plt.xlim(xlim)
    plt.xlabel(f'$x$')
    plt.ylabel(f'$u$')
    plt.title(f'Wave Equation')
    plt.legend(loc='lower right')
    plt.tight_layout()
    fig.canvas.draw()

# %%
# =============================================================================
# Noise robustness experiment -- helpers
# -----------------------------------------------------------------------------
# Variables used from globals (read-only): a, u, config, device, FNN2d, Adam,
#   DataLoader1D, train_wave, PINO_loss_wave, LpLoss, np, torch.
# =============================================================================

import copy

def add_gaussian_noise(u_clean, rel_std, seed=0):
    if rel_std <= 0:
        return u_clean.clone()
    gen = torch.Generator(device=u_clean.device).manual_seed(int(seed))
    sigma = rel_std * u_clean.std()
    noise = torch.randn(u_clean.shape, generator=gen,
                        device=u_clean.device, dtype=u_clean.dtype) * sigma
    return u_clean + noise

def eval_clean_metrics(model, dataloader, c, device):
    model.eval()
    myloss = LpLoss(size_average=True)
    rel_l2_list, f_list = [], []
    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            out = model(x).reshape(y.shape)
            rel_l2_list.append(myloss(out, y).item())
            _, f_loss = PINO_loss_wave(out, x[:, 0, :, 0], c=c)
            f_list.append(f_loss.item())
    return float(np.mean(rel_l2_list)), float(np.mean(f_list))

# %%
# =============================================================================
# Noise robustness sweep
# -----------------------------------------------------------------------------
# For each noise level, build a noisy training loader from u, retrain a fresh
# FNN2d from scratch, then evaluate on a CLEAN test loader so the metric stays
# directly comparable across runs and to the baseline.
#
# =============================================================================

noise_levels = [0.0, 0.01, 0.05, 0.10, 0.20]
noise_seed = 0
noise_epochs = 500
noise_milestones = [150, 300, 450]

n_train_n = config['data']['n_train']
n_test_n  = config['data']['n_test']
train_bs_n = config['train']['batchsize']
test_bs_n  = config['test']['batchsize']
c_n = config['data']['c']

sweep_config = copy.deepcopy(config)
sweep_config['train']['save_dir']   = 'Wave/noise_sweep'
sweep_config['train']['ckpt_freq']  = 10**9
sweep_config['train']['epochs']     = noise_epochs
sweep_config['train']['milestones'] = noise_milestones

clean_dataset = DataLoader1D(a, u,
                             config['data']['nx'], config['data']['nt'],
                             config['data']['sub'], config['data']['sub_t'])
test_loader_clean = clean_dataset.make_loader(n_test_n, test_bs_n,
                                              start=n_train_n, train=False)

noise_results = []
for lvl in noise_levels:
    print(f"\n=== Training-data noise level: {lvl*100:.0f}% of signal std ===")

    u_noisy = add_gaussian_noise(u, lvl, seed=noise_seed)

    noisy_dataset = DataLoader1D(a, u_noisy,
                                 config['data']['nx'], config['data']['nt'],
                                 config['data']['sub'], config['data']['sub_t'])
    train_loader_noisy = noisy_dataset.make_loader(n_train_n, train_bs_n,
                                                   start=0, train=True)

    sweep_config['train']['save_name'] = f'Wave-eqn_noise_{int(round(lvl*100)):02d}.pt'

    torch.manual_seed(noise_seed)
    model_n = FNN2d(modes1=config['model']['modes1'],
                    modes2=config['model']['modes2'],
                    fc_dim=config['model']['fc_dim'],
                    layers=config['model']['layers'],
                    activation=config['model']['activation']).to(device)
    optimizer_n = Adam(model_n.parameters(), betas=(0.9, 0.999),
                       lr=config['train']['base_lr'])
    scheduler_n = torch.optim.lr_scheduler.MultiStepLR(
        optimizer_n,
        milestones=sweep_config['train']['milestones'],
        gamma=sweep_config['train']['scheduler_gamma'],
    )

    train_wave(model_n, train_loader_noisy, optimizer_n, scheduler_n,
               sweep_config, rank=3, log=False,
               project=config['log']['project'], group=config['log']['group'],
               use_tqdm=True)

    rel_l2, residual = eval_clean_metrics(model_n, test_loader_clean, c_n, device)
    print(f"  -> rel L2 (clean test): {rel_l2:.5f}   eq residual: {residual:.5e}")
    noise_results.append((lvl, rel_l2, residual))

    del model_n, optimizer_n, scheduler_n
    torch.cuda.empty_cache()

noise_results = np.array(noise_results)
print("\nnoise_results shape:", noise_results.shape,
      "  columns: [noise_level, rel_L2, eq_residual]")
# Out:
# === Training-data noise level: 0% of signal std ===
# Epoch 0, train loss: 10.37896 train f error: 0.27874; data l2 error: 1.00630; train ic error: 0.33503:   0%|          | 1/500 [00:01<12:37,  1.52s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_00_0.pt
# Epoch 499, train loss: 0.08438 train f error: 0.07227; data l2 error: 0.00121; train ic error: 0.00000: 100%|██████████| 500/500 [12:24<00:00,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_00.pt
# Done!
#   -> rel L2 (clean test): 0.00114   eq residual: 7.55182e-02
#
# === Training-data noise level: 1% of signal std ===
# Epoch 0, train loss: 10.37894 train f error: 0.27875; data l2 error: 1.00630; train ic error: 0.33503:   0%|          | 1/500 [00:01<12:38,  1.52s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_01_0.pt
# Epoch 499, train loss: 0.17995 train f error: 0.05240; data l2 error: 0.01275; train ic error: 0.00001: 100%|██████████| 500/500 [12:24<00:00,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_01.pt
# Done!
#   -> rel L2 (clean test): 0.00496   eq residual: 5.53405e-02
#
# === Training-data noise level: 5% of signal std ===
# Epoch 0, train loss: 10.37880 train f error: 0.27898; data l2 error: 1.00626; train ic error: 0.33503:   0%|          | 1/500 [00:01<12:47,  1.54s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_05_0.pt
# Epoch 499, train loss: 0.62274 train f error: 0.02566; data l2 error: 0.05971; train ic error: 0.00002: 100%|██████████| 500/500 [12:24<00:00,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_05.pt
# Done!
#   -> rel L2 (clean test): 0.01307   eq residual: 2.77893e-02
#
# === Training-data noise level: 10% of signal std ===
# Epoch 0, train loss: 10.37793 train f error: 0.27948; data l2 error: 1.00612; train ic error: 0.33503:   0%|          | 1/500 [00:01<12:46,  1.54s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_10_0.pt
# Epoch 499, train loss: 1.18424 train f error: 0.01478; data l2 error: 0.11695; train ic error: 0.00003: 100%|██████████| 500/500 [12:24<00:00,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_10.pt
# Done!
#   -> rel L2 (clean test): 0.01844   eq residual: 1.61092e-02
#
# === Training-data noise level: 20% of signal std ===
# Epoch 0, train loss: 10.37442 train f error: 0.28063; data l2 error: 1.00566; train ic error: 0.33501:   0%|          | 1/500 [00:01<12:42,  1.53s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_20_0.pt
# Epoch 499, train loss: 2.26837 train f error: 0.00707; data l2 error: 0.22613; train ic error: 0.00003: 100%|██████████| 500/500 [12:24<00:00,  1.49s/it]
# Checkpoint is saved at checkpoints/Wave/noise_sweep/Wave-eqn_noise_20.pt
# Done!
#   -> rel L2 (clean test): 0.02418   eq residual: 7.75338e-03
#
# noise_results shape: (5, 3)   columns: [noise_level, rel_L2, eq_residual]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
ax.plot(noise_results[:, 0] * 100, noise_results[:, 1], 'o-', color='tab:blue')
ax.set_xlabel('Training noise level (% of signal std)')
ax.set_ylabel('Relative L2 error (clean test)')
ax.set_title('Prediction error vs training noise')
ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(noise_results[:, 0] * 100, noise_results[:, 2], 's-', color='tab:orange')
ax.set_xlabel('Training noise level (% of signal std)')
ax.set_ylabel('PDE equation residual (clean test)')
ax.set_title('Physics residual vs training noise')
ax.set_yscale('log')
ax.grid(True, alpha=0.3, which='both')

plt.tight_layout()
plt.show()
